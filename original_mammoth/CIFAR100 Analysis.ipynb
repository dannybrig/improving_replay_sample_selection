# %% [markdown]
# ### DER via Reservoir -- Class-IL Split-CIFAR100

# %% [markdown]
# #### Buffer Size = 200

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [88.6, 41.0, 36.6, 39.2, 23.3, 23.59, 18.9, 15.9, 10.7, 14.7]
task2_accs = [85.1, 28.79, 17.2, 9.8, 9.8, 10.1, 7.0, 8.4, 8.7]
task3_accs = [87, 43.2, 20.59, 24.2, 16.1, 8.6, 9.2, 10.4]
task4_accs = [85.39, 25.3, 19.7, 15.2, 15.2, 11.89, 6.9]
task5_accs = [88.1, 38.9, 29.7, 23.3, 22.0, 18.3]
task6_accs = [89.7, 43.6, 40.5, 30.2, 17.5]
task7_accs = [88.8, 17.59, 21.7, 9.7]
task8_accs = [86.1, 34, 20.4]
task9_accs = [88.2, 27.5]
task10_accs = [91.2]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/cifar100_original_200.png')

plt.show()


print('Forgetting:', 72.54)
# Out:
# Forgetting: 72.54

# %% [markdown]
# #### Buffer Size = 500

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [88.4, 61.4, 49.6, 44.9, 38.2, 33.1, 34.0, 28.99, 19.6, 22]
task2_accs = [82.5, 50.5, 34.8, 33.7, 28.7, 29.4, 27.20, 17.7, 18.5]
task3_accs = [85.1, 56.49, 44.9, 47.59, 39.7, 33.90, 33.4, 28.79]
task4_accs = [85.2, 51.6, 42.69, 39.30, 35.6, 33.0, 22.90]
task5_accs = [82.89, 44.3, 42.5, 33.6, 31.90, 26.1]
task6_accs = [83.1, 37.4, 28.19, 25.6, 15.6]
task7_accs = [84.39, 37.2, 40.2, 35.8]
task8_accs = [83.7, 38.6, 26.6]
task9_accs = [85.5, 44.3]
task10_accs = [88.3]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/cifar100_original_500.png')

plt.show()


print('Forgetting:', 57.80)
# Out:
# Forgetting: 57.8

# %% [markdown]
# #### Buffer Size = 5120

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [88.4, 74.4, 67.7, 67.3, 66.10, 59.19, 62.4, 60.3, 56.99, 57.49]
task2_accs = [80.6, 66.2, 61.3, 59.09, 61.6, 58.69, 57.19, 50.3, 50.6]
task3_accs = [82.39, 68.89, 68.89, 66.9, 65.0, 61.5, 63.6, 60.8]
task4_accs = [80.7, 66.4, 62.6, 60.5, 59.5, 59.69, 53.0]
task5_accs = [74.2, 54.5, 58.59, 57.59, 59.19, 57.49]
task6_accs = [80.1, 63.5, 59.9, 62.5, 62.2]
task7_accs = [77.7, 53.80, 61.1, 59.4]
task8_accs = [74.2, 54.1, 46.0]
task9_accs = [80.80, 55.2]
task10_accs = [73.2]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/cifar100_original_5120.png')

plt.show()


print('Forgetting:', 24.10)
# Out:
# Forgetting: 24.1

# %% [markdown]
# #### Intracluster Variance

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [88.7, 70.6, 71.5, 69, 65.3, 65.4, 65.3, 63.3, 59, 62.2]
task2_accs = [84.3, 66.3, 59.5, 59.19, 57.3, 55.90, 59.89, 53, 55.1]
task3_accs = [85, 70.89, 68.4, 67.3, 66.4, 64.9, 63.5, 63.2]
task4_accs = [83.89, 69.39, 64.3, 64.2, 64.8, 60.5, 56.69]
task5_accs = [81.5, 63.4, 65.3, 63.2, 62, 61]
task6_accs = [85.3, 65.2, 61.5, 64.9, 63.8]
task7_accs = [81.89, 62.5, 64.6, 64.4]
task8_accs = [79, 60, 54.8]
task9_accs = [84.1, 65.7]
task10_accs = [76.7]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/cifar100_original_intracluster_variance.png')

plt.show()


print('Forgetting:', 22.97)
# Out:
# Forgetting: 22.97

# %% [markdown]
# #### Kaiser Criterion

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [88.5, 60, 60.8, 59.9, 55.3, 53.3, 51.1, 50.3, 45.7, 47.5]
task2_accs = [84.7, 60.8, 53.9, 52.5, 53.2, 51.4, 48, 43.5, 44.6]
task3_accs = [88, 67.8, 56.9, 59.8, 54.7, 52.1, 53.5, 52.4]
task4_accs = [85.7, 66.8, 62.5, 60.16, 59.3, 57.89, 48.3]
task5_accs = [85.6, 62.9, 60.3, 55.2, 55.7, 51.8]
task6_accs = [86.9, 64.1, 64.6, 65.5, 59.5]
task7_accs = [85.2, 60.8, 64.3, 58.5]
task8_accs = [82.1, 59.59, 51.7]
task9_accs = [83.39, 67.8]
task10_accs = [83.8]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/cifar100_original_kaiser_criterion.png')

plt.show()


print('Forgetting:', 31.99)
# Out:
# Forgetting: 31.99

# %% [markdown]
# ### ER via Reservoir -- Class-IL Split-CIFAR100

# %% [markdown]
# #### Buffer Size = 200

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [85.1, 24.7, 14.49, 14.09, 10.8, 8.2, 5.7, 5.4, 1.09, 4.2]
task2_accs = [84.89, 26, 9.4, 6.7, 5.6, 4.8, 3.8, 2.19, 2.5]
task3_accs = [87.3, 27.9, 11.5, 15, 9.7, 5.3, 4.1, 4.8]
task4_accs = [87, 20.5, 12.7, 7.6, 5.4, 5.2, 3.1]
task5_accs = [88.9, 25.8, 19.8, 11.8, 5.8, 6.5]
task6_accs = [88.5, 26.2, 20.2, 11.3, 6.2]
task7_accs = [89.3, 10.9, 11.2, 6.6]
task8_accs = [88.3, 14.6, 7.8]
task9_accs = [90.1, 11.7]
task10_accs = [93]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/cifar100_original_200.png')

plt.show()

print('Forgetting:', 81.77)
# Out:
# Forgetting: 81.77

# %% [markdown]
# #### Buffer Size = 500

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [85.1, 37.7, 32.6, 26.3, 20.5, 18.09, 17, 14.4, 7.3, 10.6]
task2_accs = [82.3, 39.9, 20.7, 17.2, 14.2, 13.5, 9.7, 6.4, 7.1]
task3_accs = [84.89, 38.1, 25.5, 25.5, 19.8, 14.0, 13.4, 12]
task4_accs = [84.8, 29.7, 21.0, 16.5, 12.5, 10.6, 5]
task5_accs = [87.2, 32.3, 27.1, 23.2, 18.5, 15.2]
task6_accs = [87.5, 35.9, 29.09, 20, 10.4]
task7_accs = [88.1, 18.8, 16.1, 10.8]
task8_accs = [86.6, 29.2, 17]
task9_accs = [89.4, 16.3]
task10_accs = [92.4]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/cifar100_original_500.png')

plt.show()

print('Forgetting:', 74.62)
# Out:
# Forgetting: 74.62

# %% [markdown]
# #### Buffer Size = 5120

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [89.2, 76.9, 69, 64.6, 60.4, 56.59, 55.4, 50.1, 46.9, 46.2]
task2_accs = [82.6, 68.89, 58.69, 56.49, 55.1, 49, 46, 39.7, 40.2]
task3_accs = [85, 71.3, 56.69, 58.4, 57.69, 52.8, 52.9, 50.2]
task4_accs = [86.6, 66.9, 62.8, 56.59, 52.6, 46.7, 38.5]
task5_accs = [85.5, 61.4, 55.6, 51.6, 47.1, 42.1]
task6_accs = [86.5, 67.4, 56.9, 53.7, 43.8]
task7_accs = [84.8, 54.7, 54.1, 48.5]
task8_accs = [85.1, 63.1, 49.5]
task9_accs = [87.7, 57.8]
task10_accs = [89]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/cifar100_original_5120.png')

plt.show()

print('Forgetting:', 39.56)
# Out:
# Forgetting: 39.56

# %% [markdown]
# #### Intracluster Variance

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [87.1, 63.2, 59.69, 56.5, 55.9, 50.7, 51.5, 52, 49.3, 48.3]
task2_accs = [84.3, 62.9, 52.6, 50.5, 50, 46.1, 45.4, 45.2, 43.2]
task3_accs = [85.7, 66.6, 60, 62.8, 57.69, 54.3, 55, 54.9]
task4_accs = [85.7, 62.2, 59.19, 53.2, 53.8, 52.1, 46]
task5_accs = [85.3, 64.5, 61.8, 58.5, 56.89, 51.5]
task6_accs = [86.2, 68.4, 61.19, 58.89, 56.59]
task7_accs = [85.7, 60.19, 57.99, 53.5]
task8_accs = [81.69, 65.6, 52.5]
task9_accs = [85.8, 64.3]
task10_accs = [86]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/cifar100_original_intracluster_variance.png')

plt.show()

print('Forgetting:', 32.9)
# Out:
# Forgetting: 32.9

# %% [markdown]
# #### Kaiser Criterion

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [86.1, 46.30, 43.4, 43.1, 39, 35.19, 36, 37.1, 34.8, 34.3]
task2_accs = [83.89, 52.9, 40.40, 39, 37.5, 35.19, 35.4, 31.8, 30.3]
task3_accs = [87.1, 56.9, 45.3, 47.8, 43.1, 42, 39.4, 40.9]
task4_accs = [86.2, 52.7, 47.3, 42.5, 43.1, 43, 33.2]
task5_accs = [86.5, 57.49, 52.90, 49, 45.1, 37.6]
task6_accs = [86.5, 61.8, 54.2, 51.9, 45.8]
task7_accs = [85.8, 48, 50.7, 42.19]
task8_accs = [85.7, 58.5, 44.3]
task9_accs = [87.9, 61]
task10_accs = [88.2]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/cifar100_original_kaiser_criterion.png')

plt.show()

print('Forgetting:', 45.12)
# Out:
# Forgetting: 45.12

# %% [markdown]
# ### ER-ACE via Reservoir -- Class -IL Split-CIFAR100

# %% [markdown]
# #### Buffer Size = 200

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [87.3, 55.5, 39.4, 30.2, 26.4, 26.6, 17.2, 15.9, 13.1, 13.7]
task2_accs = [76.8, 56.2, 38.5, 30.5, 23.1, 22.8, 18.7, 19.4, 16.1]
task3_accs = [78.9, 53.6, 40.3, 34.69, 29.79, 22.8, 21.2, 20.7]
task4_accs = [71.2, 47.4, 39.9, 32.6, 25.3, 22.8, 24]
task5_accs = [74.2, 46.7, 33.7, 30.5, 31.8, 28.1]
task6_accs = [72.2, 48.4, 45.5, 35.8, 29.9]
task7_accs = [67.8, 39.7, 30.8, 29.9]
task8_accs = [57.49, 32.3, 27.3]
task9_accs = [64, 46]
task10_accs = [44]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/cifar100_original_200.png')

plt.show()

print('Forgetting:', 46.01)
# Out:
# Forgetting: 46.01

# %% [markdown]
# #### Buffer Size = 500

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [88.5, 67.3, 56.3, 52.6, 42.9, 41.9, 42.9, 35.9, 35.09, 33.1]
task2_accs = [78.6, 58.5, 46.9, 39.8, 31.6, 28.4, 27.4, 24.09, 23.3]
task3_accs = [78.5, 62.9, 51.6, 48.9, 41.9, 34.4, 30.8, 29.2]
task4_accs = [73.6, 50.5, 44.3, 36.6, 29.7, 28.0, 25.9]
task5_accs = [76.4, 52.2, 44.6, 41, 38.8, 36.9]
task6_accs = [74.8, 55.5, 45.1, 40.2, 38]
task7_accs = [72.8, 50.2, 45.4, 39.8]
task8_accs = [67.1, 46.3, 44]
task9_accs = [63.5, 47.5]
task10_accs = [56.8]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/cifar100_original_500.png')

plt.show()

print('Forgetting:', 39.56)
# Out:
# Forgetting: 39.56

# %% [markdown]
# #### Buffer Size = 5120

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [87.7, 81, 75.9, 70.8, 54.8, 61.6, 58.69, 56.59, 54.7, 54.2]
task2_accs = [80, 74.1, 65.5, 59.4, 59.5, 57.09, 54.6, 51.1, 47.8]
task3_accs = [79.1, 72.3, 66.9, 64.8, 61.3, 58.3, 59, 58.9]
task4_accs = [75.5, 67.3, 64.4, 59.59, 57.59, 56.89, 50]
task5_accs = [76, 65.8, 62.6, 60.1, 57.4, 54.4]
task6_accs = [75.2, 66.1, 62.1, 59, 54.4]
task7_accs = [72.7, 63.8, 59.9, 57.1]
task8_accs = [68.8, 61.3, 56.2]
task9_accs = [61.3, 63.4]
task10_accs = [69.89]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/cifar100_original_5120.png')

plt.show()

print('Forgetting:', 22.24)
# Out:
# Forgetting: 22.24

# %% [markdown]
# #### Intracluster Variance

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [88.2, 69.1, 65.3, 62.8, 60.4, 58.4, 56.8, 56.6, 55.9, 54.8]
task2_accs = [83.3, 71.1, 59.5, 58.19, 55.8, 53, 53.5, 49, 48.6]
task3_accs = [83.7, 73.3, 65.6, 65, 63.3, 60.4, 59.9, 57.8]
task4_accs = [84.3, 68.8, 65.9, 60.4, 57.4, 56.3, 50.7]
task5_accs = [82.1, 66.5, 65.9, 62.4, 60.3, 56.2]
task6_accs = [82.69, 72.3, 66.2, 64.7, 61.1]
task7_accs = [80.5, 65.4, 63.7, 59.3]
task8_accs = [75.9, 64, 55.0]
task9_accs = [79.8, 71.2]
task10_accs = [78.7]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/cifar100_original_intracluster_variance.png')

plt.show()

print('Forgetting:', 25.07)
# Out:
# Forgetting: 25.07

# %% [markdown]
# #### Kaiser Criterion

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [88.7, 60.5, 52.5, 48.4, 45.8, 42.9, 44.8, 42, 42.1, 39.5]
task2_accs = [84.8, 61.1, 52.4, 48.3, 48.5, 46.4, 47.8, 40.2, 37.3]
task3_accs = [86.6, 64.9, 54.8, 55.6, 52.1, 50.5, 49.9, 51.7]
task4_accs = [85.9, 66.3, 57.49, 51.5, 54.9, 49.5, 44.7]
task5_accs = [85.39, 61.4, 55.6, 53.1, 51.2, 45.4]
task6_accs = [84.3, 68.4, 61.3, 57.6, 54.1]
task7_accs = [85.1, 58.4, 55.7, 52.3]
task8_accs = [82.1, 62.5, 50]
task9_accs = [83.7, 67.6]
task10_accs = [84.2]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/cifar100_original_kaiser_criterion.png')

plt.show()

print('Forgetting:', 36.01)
# Out:
# Forgetting: 36.01
