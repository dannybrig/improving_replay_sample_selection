# %% [markdown]
# ### DER via Reservoir -- Class-IL Split-CIFAR10

# %% [markdown]
# #### Buffer Size = 200

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [98.85, 84.40, 69.65, 65.15, 31.90]
task2_accs = [85.8, 50.2, 31.6, 30.85]
task3_accs = [89.25, 53.05, 53.90]
task4_accs = [95.6, 84.85]
task5_accs = [96.75]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/cifar10_original_200.png')

plt.show()

print('Forgetting:', 42.0)
# Out:
# Forgetting: 42.0

# %% [markdown]
# #### Buffer Size = 500

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [98.55, 89.45, 89.55, 82.89, 51.6]
task2_accs = [89.9, 53.44, 39.95, 49.7]
task3_accs = [91.0, 63.4, 64.45]
task4_accs = [96.55, 85.05]
task5_accs = [94.75]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/cifar10_original_500.png')

plt.show()

print('Forgetting:', 31.3)
# Out:
# Forgetting: 31.3

# %% [markdown]
# #### Buffer Size = 5120

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [98.7, 95.1, 93.95, 92.80, 84.05]
task2_accs = [89.55, 73.85, 72.39, 60.09]
task3_accs = [88.94, 80.02, 83.39]
task4_accs = [91.95, 91.15]
task5_accs = [92.9]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/cifar10_original_5120.png')

plt.show()

print('Forgetting:', 12.61)
# Out:
# Forgetting: 12.61

# %% [markdown]
# #### Intracluster Variance

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [99.05, 67.9, 73.85, 76.8, 55.75]
task2_accs = [93.7, 34.69, 35.65, 35.4]
task3_accs = [95.8, 68.3, 65.3]
task4_accs = [96.35, 90.60]
task5_accs = [96.45]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/cifar10_original_intracluster_variance.png')

plt.show()

print('Forgetting:', 34.46)
# Out:
# Forgetting: 34.46

# %% [markdown]
# #### Kaiser Criterion

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [99, 84.45, 85.95, 95.35, 71.25]
task2_accs = [92.15, 52.34, 49.45, 45.95]
task3_accs = [94.45, 77.9, 77.3]
task4_accs = [96.1, 93.45]
task5_accs = [95.35]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/cifar10_original_kaiser_criterion.png')

plt.show()

print('Forgetting:', 23.4375)
# Out:
# Forgetting: 23.4375

# %% [markdown]
# ### ER via Reservoir -- Class-IL Split-CIFAR10

# %% [markdown]
# #### Buffer Size = 200

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [98.45, 61.3, 65.2, 60.09, 22.75]
task2_accs = [91.95, 14.79, 7.04, 13.15]
task3_accs = [95.85, 23.15, 35.94]
task4_accs = [99.1, 64.35]
task5_accs = [97.95]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/cifar10_original_200.png')

plt.show()

print('Forgetting:', 62.2875)
# Out:
# Forgetting: 62.2875

# %% [markdown]
# #### Buffer Size = 500

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [98.8, 76.25, 75.35, 68, 32.75]
task2_accs = [92.85, 25.7, 21.5, 30.15]
task3_accs = [95.35, 43.55, 60.69]
task4_accs = [98.65, 79.14]
task5_accs = [98.25]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/cifar10_original_500.png')

plt.show()

print('Forgetting:', 45.72)
# Out:
# Forgetting: 45.72

# %% [markdown]
# #### Buffer Size = 5120

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [98.65, 94.15, 92.75, 92.65, 79.75]
task2_accs = [91.5, 76.44, 64.60, 55.90]
task3_accs = [90.75, 78.25, 85]
task4_accs = [97.89, 92.60]
task5_accs = [95.85]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/cifar10_original_5120.png')

plt.show()

print('Forgetting:', 16.38)
# Out:
# Forgetting: 16.38

# %% [markdown]
# #### Intracluster Variance

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [98.75, 66.75, 72.39, 75.64, 45.6]
task2_accs = [93.1, 25.8, 28.7, 36.3]
task3_accs = [95.05, 47.5, 61.35]
task4_accs = [98.7, 84.25]
task5_accs = [97.89]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/cifar10_original_intracluster_variance.png')

plt.show()

print('Forgetting:', 39.525)
# Out:
# Forgetting: 39.525

# %% [markdown]
# #### Kaiser Criterion

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [98.55, 86.05, 84.2, 84.85, 66.2]
task2_accs = [91.3, 46.05, 41.34, 51.2]
task3_accs = [94.55, 61.6, 70.1]
task4_accs = [98.35, 90.5]
task5_accs = [97.05]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/cifar10_original_kaiser_criterion.png')

plt.show()

print('Forgetting:', 26.187)
# Out:
# Forgetting: 26.187

# %% [markdown]
# ### ER-ACE via Reservoir -- Class-IL Split-CIFAR10

# %% [markdown]
# #### Buffer Size = 200

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [98.55, 93.75, 88.5, 88.14, 75.14]
task2_accs = [75.8, 61.35, 50.14, 46.3]
task3_accs = [70.55, 49.15, 39.5]
task4_accs = [88.5, 85.8]
task5_accs = [54.35]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/cifar10_original_200.png')

plt.show()

print('Forgetting:', 21.66)
# Out:
# Forgetting: 21.66

# %% [markdown]
# #### Buffer Size = 500

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [98.85, 91.4, 91.8, 88.35, 79.3]
task2_accs = [83.75, 71.05, 60.85, 53.05]
task3_accs = [76.5, 70.7, 68.4]
task4_accs = [84.45, 82.95]
task5_accs = [76.14]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/cifar10_original_500.png')

plt.show()

print('Forgetting:', 14.96)
# Out:
# Forgetting: 14.96

# %% [markdown]
# #### Buffer Size = 5120

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [98.75, 98.15, 95.89, 93.89, 85.39]
task2_accs = [84, 80.30, 75.4, 80.4]
task3_accs = [79.9, 81.35, 77.55]
task4_accs = [83.65, 86.4]
task5_accs = [86.75]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/cifar10_original_5120.png')

plt.show()

print('Forgetting:', 5.18)
# Out:
# Forgetting: 5.18

# %% [markdown]
# #### Intracluster Variance

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [99, 81.05, 84.7, 85.45, 64.2]
task2_accs = [92.3, 43.25, 39.05, 45.5]
task3_accs = [93.8, 62.1, 65.55]
task4_accs = [97.85, 91.64]
task5_accs = [96.15]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/cifar10_original_intracluster_variance.png')

plt.show()

print('Forgetting:', 29.0125)
# Out:
# Forgetting: 29.0125

# %% [markdown]
# #### Kaiser Criterion

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [98.85, 86.8, 90.8, 88.25, 67.45]
task2_accs = [91.8, 59.19, 58.45, 55.1]
task3_accs = [92.75, 73.6, 83.15]
task4_accs = [95.55, 91.4]
task5_accs = [95.5]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/cifar10_original_kaiser_criterion.png')

plt.show()

print('Forgetting:', 20.46)
# Out:
# Forgetting: 20.46
