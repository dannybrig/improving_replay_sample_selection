# %% [markdown]
# ### DER via Reservoir -- Class-IL Split-TinyImageNet

# %% [markdown]
# #### Buffer Size = 200

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [78.4, 28.7, 16.6, 11.4, 6.3, 6.9, 5.7, 5.7, 2.6, 2.1]
task2_accs = [73.2, 6.7, 3, 1.5, 2.9, 1.3, 1.6, 0.4, 0.2]
task3_accs = [80.4, 15.29, 8, 11.7, 4.5, 3.3, 2.4, 1.6]
task4_accs = [82.6, 16.2, 11.7, 6.9, 5.3, 3.9, 5]
task5_accs = [80.7, 9.1, 5.8, 2.4, 1.5, 1.4]
task6_accs = [78.1, 7.7, 5.7, 2.3, 1.4]
task7_accs = [79.4, 9.4, 4.1, 3.4]
task8_accs = [78.7, 11.3, 6.6]
task9_accs = [72.8, 9.5]
task10_accs = [78]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/tinyimg_original_200.png')

plt.show()

print('Forgetting:', 74.78)
# Out:
# Forgetting: 74.78

# %% [markdown]
# #### Buffer Size = 500

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [79.60, 40.4, 32.1, 18.6, 19.9, 15.6, 17.5, 16.2, 16.1, 9.9]
task2_accs = [72.3, 22.6, 9.7, 8.5, 9, 7.8, 7.39, 5.6, 6]
task3_accs = [78.5, 21.8, 16.1, 13.2, 12.8, 12.6, 11.6, 9.9]
task4_accs = [76.8, 26, 14.0, 11.79, 12.1, 9.8, 8.4]
task5_accs = [80.1, 14.39, 12.4, 8.7, 6.6, 7.1]
task6_accs = [80, 16.4, 9.8, 7.9, 4.8]
task7_accs = [78.8, 20, 13.3, 6.9]
task8_accs = [78.7, 16.6, 11]
task9_accs = [71.5, 8.3]
task10_accs = [82.1]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/tinyimg_original_500.png')

plt.show()

print('Forgetting:', 69.33)
# Out:
# Forgetting: 69.33

# %% [markdown]
# #### Buffer Size = 5120

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [80.1, 67.2, 65.8, 63.1, 60.5, 57.49, 59.99, 54.7, 52.7, 47.5]
task2_accs = [67.7, 47.9, 45.1, 41.9, 42.69, 42.3, 41.3, 39.6, 37.5]
task3_accs = [70.5, 50.7, 49.4, 48.4, 45.6, 47.4, 43.9, 39.7]
task4_accs = [72.1, 50.5, 51.5, 48.3, 49.1, 46.1, 44.7]
task5_accs = [66.4, 37.3, 33.6, 35.09, 31.7, 33.3]
task6_accs = [59.4, 26.1, 26.9, 27.3, 27.5]
task7_accs = [65.7, 30.9, 29.5, 24.8]
task8_accs = [60.5, 28.19, 27.9]
task9_accs = [58.09, 17]
task10_accs = [64.1]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/tinyimg_original_5120.png')

plt.show()

print('Forgetting:', 33.4)
# Out:
# Forgetting: 33.4

# %% [markdown]
# #### Intracluster Variance

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [80.5, 63.5, 66.5, 66.8, 71.5, 64.3, 66.1, 67.3, 66.4, 61.4]
task2_accs = [67.4, 42.5, 43.7, 46.6, 43.3, 44, 44.4, 44.9, 44]
task3_accs = [71.2, 55.1, 54.2, 51.8, 54.1, 51.9, 54.1, 55.4]
task4_accs = [73.3, 49.4, 43.6, 49.2, 48.8, 50.6, 50.5]
task5_accs = [62, 29.79, 36.6, 36.6, 41.09, 41.69]
task6_accs = [63.6, 23, 25.7, 31, 33.8]
task7_accs = [66.7, 33.2, 32.9, 30]
task8_accs = [59.3, 25.3, 29.29]
task9_accs = [53.8, 15.5]
task10_accs = [62.2]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/tinyimg_original_intracluster_variance.png')

plt.show()

print('Forgetting:', 26.24)
# Out:
# Forgetting: 26.24

# %% [markdown]
# #### Kaiser Criterion

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [81.1, 63.9, 66, 62.1, 59.8, 62.1, 53.5, 52, 53.5, 47.8]
task2_accs = [67.8, 40, 42.8, 38.3, 41.6, 40.5, 40.6, 37.5, 37.2]
task3_accs = [73.2, 54.6, 50.1, 50.6, 50.4, 47.59, 47.89, 46.5]
task4_accs = [75.1, 48.19, 50.8, 47.19, 49, 47.8, 47.3]
task5_accs = [71.3, 40.40, 39.5, 40.6, 37.6, 39.3]
task6_accs = [64.5, 37, 36.1, 38.2, 34.5]
task7_accs = [71.7, 44.2, 43.2, 38.4]
task8_accs = [68.7, 31.7, 32.1]
task9_accs = [61.19, 28.99]
task10_accs = [68.8]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/tinyimg_original_kaiser_criterion.png')

plt.show()

print('Forgetting:', 31.38)
# Out:
# Forgetting: 31.38

# %% [markdown]
# ### ER via Reservoir -- Class-IL Split-TinyImageNet

# %% [markdown]
# #### Buffer Size = 200

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [78.3, 10.29, 2.7, 1.6, 0.8, 0.3, 0.1, 0, 0, 0]
task2_accs = [71.3, 6.2, 2.8, 1.2, 1.6, 1, 0.89, 0.4, 0.8]
task3_accs = [77.2, 8.3, 1.3, 1.2, 0.89, 0.3, 0.3, 0.1]
task4_accs = [81, 6.3, 3.5, 2, 1.4, 0.6, 0.4]
task5_accs = [79.1, 3.69, 2.3, 0.6, 0.2, 0.5]
task6_accs = [78.9, 1.5, 1.3, 0.1, 0.3]
task7_accs = [79.9, 1.5, 0.59, 0.3]
task8_accs = [78.7, 2, 1.09]
task9_accs = [74.7, 1.2]
task10_accs = [80.60]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/tinyimg_original_200.png')

plt.show()

print('Forgetting:', 77.15)
# Out:
# Forgetting: 77.15

# %% [markdown]
# #### Buffer Size = 500

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [77, 22.9, 12.6, 8.1, 5.3, 3.9, 3.3, 2.19, 1.9, 2.1]
task2_accs = [72.1, 13.4, 5.89, 3.5, 2.4, 1.7, 1.4, 1.3, 1.4]
task3_accs = [77.3, 16.9, 5.89, 3.5, 3.2, 1.7, 1, 1.3]
task4_accs = [80.8, 16.1, 8.3, 2.6, 3.1, 2, 1.7]
task5_accs = [81.5, 6.1, 4.1, 2.6, 1.09, 1.7]
task6_accs = [79, 8.7, 4.3, 3.69, 2.4]
task7_accs = [79.3, 9, 6, 3.1]
task8_accs = [79.5, 7.00, 5.5]
task9_accs = [75.4, 2.6]
task10_accs = [81.89]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/tinyimg_original_500.png')

plt.show()

print('Forgetting:', 75.55)
# Out:
# Forgetting: 75.55

# %% [markdown]
# #### Buffer Size = 5120

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [78.60, 58.4, 50.1, 45.1, 36.9, 32, 26.5, 26.6, 21.8, 16.8]
task2_accs = [72, 44.3, 34.9, 29.5, 24.8, 24, 20.5, 15.8, 16]
task3_accs = [75.3, 51.7, 41.09, 32, 31.7, 25.7, 22.1, 20.1]
task4_accs = [79.7, 47.9, 35.4, 31.1, 30.3, 26.7, 23.7]
task5_accs = [77.9, 35.9, 32.6, 27.3, 22.2, 20.4]
task6_accs = [78.7, 36.3, 29.29, 23.3, 23]
task7_accs = [78.1, 36.1, 28.4, 20.5]
task8_accs = [77, 32.3, 25.6]
task9_accs = [73.1, 27]
task10_accs = [80.8]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/tinyimg_original_5120.png')

plt.show()

print('Forgetting:', 55.24)
# Out:
# Forgetting: 55.24

# %% [markdown]
# #### Intracluster Variance

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [78.9, 58.69, 55.0, 54, 50.7, 47.8, 45.4, 44.1, 45.7, 40.2]
task2_accs = [68.5, 49.8, 42.8, 42.3, 38.3, 38.8, 36.1, 33.8, 33.6]
task3_accs = [74.9, 60.3, 54.2, 49.6, 50.1, 46.7, 44.1, 41.4]
task4_accs = [77.8, 58.5, 55.0, 51, 50.6, 49.5, 47.59]
task5_accs = [73.1, 52.1, 48.8, 44.2, 43.6, 41]
task6_accs = [72.3, 50.8, 45.5, 42.6, 42.1]
task7_accs = [72.6, 52, 48.5, 42.1]
task8_accs = [70.5, 50.8, 48.3]
task9_accs = [64.1, 44.1]
task10_accs = [71.89]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/tinyimg_original_intracluster_variance.png')

plt.show()

print('Forgetting:', 30.255)
# Out:
# Forgetting: 30.255

# %% [markdown]
# #### Kaiser Criterion

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [79.5, 42.4, 38.6, 36.19, 33.4, 31.8, 30.59, 31.6, 30.4, 25.6]
task2_accs = [69.8, 32.9, 27.5, 25.9, 24.8, 24, 21.6, 18.6, 19.2]
task3_accs = [77.3, 47.9, 38.4, 32.4, 32.5, 31.4, 30.2, 29.79]
task4_accs = [79.3, 46.6, 37.2, 35.19, 37.9, 35.9, 31]
task5_accs = [78.1, 38.1, 35.9, 34.5, 31, 28.79]
task6_accs = [76.3, 44.5, 36.9, 34.1, 31.5]
task7_accs = [76.4, 43.3, 39.2, 30.89]
task8_accs = [74.6, 38.5, 33.3]
task9_accs = [69.6, 36.3]
task10_accs = [78]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/tinyimg_original_kaiser_criterion.png')

plt.show()

print('Forgetting:', 46.14)
# Out:
# Forgetting: 46.14

# %% [markdown]
# ### ER-ACE via Reservoir -- Class-IL Split-TinyImageNet

# %% [markdown]
# #### Buffer Size = 200

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [79, 45.6, 27.6, 19.5, 18.2, 14.49, 14.09, 13.3, 9.9, 10.5]
task2_accs = [66.3, 27.1, 15.2, 9.5, 9, 6.5, 6.9, 4.3, 4.3]
task3_accs = [71.3, 36, 22.5, 18.09, 19.6, 17.7, 15.29, 11.89]
task4_accs = [72.2, 31.6, 22.7, 18, 17.4, 14.7, 12.3]
task5_accs = [69.5, 32.3, 22.5, 20, 13, 15.29]
task6_accs = [57.49, 22.3, 17.8, 13.7, 14.39]
task7_accs = [56.69, 21.5, 15.6, 13.2]
task8_accs = [50.8, 17.4, 9.2]
task9_accs = [46.7, 21.6]
task10_accs = [16.9]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/tinyimg_original_200.png')

plt.show()

print('Forgetting:', 50.81)
# Out:
# Forgetting: 50.81

# %% [markdown]
# #### Buffer Size = 500

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [80.30, 52.7, 42.5, 31.2, 30.8, 24.6, 18.7, 20.2, 14.2, 10.9]
task2_accs = [66.6, 36.4, 28.19, 21.09, 18.3, 15.9, 12.9, 12.3, 12]
task3_accs = [67.3, 48, 33.8, 31.3, 26.3, 19.4, 14.0, 16.8]
task4_accs = [70.8, 37.1, 28.49, 23.7, 17.4, 14.29, 15.7]
task5_accs = [66.2, 36.1, 30.2, 21.9, 19.2, 15.4]
task6_accs = [61.1, 30.3, 28.4, 21.8, 18.7]
task7_accs = [65.9, 33.6, 25.7, 19.2]
task8_accs = [61, 36.8, 28.9]
task9_accs = [50.6, 28.49]
task10_accs = [40.69]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/tinyimg_original_500.png')

plt.show()

print('Forgetting:', 47.07)
# Out:
# Forgetting: 47.07

# %% [markdown]
# #### Buffer Size = 5120

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [79.7, 68.7, 60.9, 56.0, 51.9, 46.1, 42.9, 40.2, 35.8, 33]
task2_accs = [64.9, 51.8, 47.19, 40.6, 38.3, 34.1, 31.9, 28.9, 25]
task3_accs = [67.3, 58.09, 53.4, 48.69, 45.8, 41.69, 39, 36.6]
task4_accs = [70.19, 57.4, 52.1, 45.7, 44.4, 40.9, 38.6]
task5_accs = [67.7, 53.4, 44.9, 40.69, 38.4, 35.6]
task6_accs = [64.1, 49.9, 41.8, 40.04, 34.4]
task7_accs = [64.1, 48.3, 43.2, 40.5]
task8_accs = [63.7, 44, 38]
task9_accs = [55.0, 40.9]
task10_accs = [59]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/tinyimg_original_5120.png')

plt.show()

print('Forgetting:', 30.45)
# Out:
# Forgetting: 30.45

# %% [markdown]
# #### Intracluster Variance

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [79.7, 63.1, 60.5, 55.6, 53.40, 50.9, 50.7, 48.9, 47.5, 44.5]
task2_accs = [72.6, 53.9, 48.4, 45.1, 40, 40.69, 39.4, 36.3, 36.1]
task3_accs = [73.4, 64.1, 57.49, 54.3, 54.1, 51.1, 48.4, 47]
task4_accs = [75.4, 63.9, 60.3, 56.3, 51.9, 51.8, 48.6]
task5_accs = [71.39, 54.5, 52.4, 48.9, 46.7, 42.8]
task6_accs = [69.8, 54.7, 49.8, 47.09, 45.1]
task7_accs = [69.1, 56.1, 49.8, 46.4]
task8_accs = [66.2, 54.1, 46.1]
task9_accs = [59.3, 46.5]
task10_accs = [67.7]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/tinyimg_original_intracluster_variance.png')

plt.show()

print('Forgetting:', 25.97)
# Out:
# Forgetting: 25.97

# %% [markdown]
# #### Kaiser Criterion

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [78.4, 49.9, 47.89, 43.2, 42.5, 40.4, 36.19, 37, 35.4, 30]
task2_accs = [72, 43.3, 36.7, 32.9, 30.7, 30.8, 27.6, 24.8, 26.1]
task3_accs = [78.2, 53.7, 46.6, 41.3, 42.1, 39.5, 36.3, 33.8]
task4_accs = [79, 54.9, 47.5, 43, 42.6, 39.1, 36.6]
task5_accs = [76.3, 48.3, 46.4, 40.69, 36.19, 34.59]
task6_accs = [76.2, 48.6, 42, 37.2, 35.6]
task7_accs = [74.4, 49.8, 43.8, 38.4]
task8_accs = [72.6, 45.2, 39.7]
task9_accs = [66.7, 40.6]
task10_accs = [74.8]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/tinyimg_original_kaiser_criterion.png')

plt.show()

print('Forgetting:', 39.82)
# Out:
# Forgetting: 39.82
