# %% [markdown]
# ### DER via GSS -- Class-IL Split-CIFAR10

# %% [markdown]
# #### Buffer Size = 200

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [97.85, 8.45, 7.1, 5.45, 1.3]
task2_accs = [90.9, 16.1, 14.9, 17.2]
task3_accs = [96.3, 9.5, 15.4]
task4_accs = [98.1, 16.1]
task5_accs = [97.35]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/cifar10_gss_200.png')

plt.show()

print('Forgetting:', 82.6125)
# Out:
# Forgetting: 82.6125

# %% [markdown]
# #### Buffer Size = 500

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [98.15, 11.0, 14.14, 8.55, 9.4]
task2_accs = [92.05, 18.25, 18.28, 20.84]
task3_accs = [94.75, 49.05, 61.0]
task4_accs = [93.35, 0]
task5_accs = [96.89]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/cifar10_gss_500.png')

plt.show()

print('Forgetting:', )
# Out:
# Forgetting:

# %% [markdown]
# #### Buffer Size = 5120

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [98.75, 50.6, 60.55, 46.7, 4.8]
task2_accs = [82.85, 8.75, 15.85, 16.5]
task3_accs = [84.7, 0, 0]
task4_accs = [90.9, 0]
task5_accs = [97.89]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/cifar10_gss_5120.png')

plt.show()

print('Forgetting:', 83.975)
# Out:
# Forgetting: 83.975

# %% [markdown]
# ### ER via GSS -- Class-IL Split-CIFAR10

# %% [markdown]
# #### Buffer Size = 200

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [98.85, 59.45, 67.0, 70.25, 41.19]
task2_accs = [91.4, 11.1, 8.6, 16.95]
task3_accs = [96.2, 19.15, 34.84]
task4_accs = [98.4, 0]
task5_accs = [97.7]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/cifar10_gss_200.png')

plt.show()

print('Forgetting:', 72.9625)
# Out:
# Forgetting: 72.9625

# %% [markdown]
# #### Buffer Size = 500

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [97.7, 76.4, 86.75, 81.75, 62.8]
task2_accs = [92.35, 16.9, 16.0, 24.6]
task3_accs = [95.15, 30.45, 49.85]
task4_accs = [98.5, 0]
task5_accs = [97.65]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/cifar10_gss_500.png')

plt.show()

print('Forgetting:', 61.61)
# Out:
# Forgetting: 61.61

# %% [markdown]
# #### Buffer Size = 5120

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [97.2, 97.05, 95.55, 96.1, 92.4]
task2_accs = [86.65, 36.05, 49.6, 70.95]
task3_accs = [95.25, 0, 0]
task4_accs = [98.35, 0]
task5_accs = [96.5]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/cifar10_gss_5120.png')

plt.show()

print('Forgetting:', 53.52)
# Out:
# Forgetting: 53.52

# %% [markdown]
# ### ER-ACE via GSS -- Class-IL Split CIFAR10

# %% [markdown]
# #### Buffer Size = 200

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [98.45, 92.8, 93.95, 95.15, 92.7]
task2_accs = [58.45, 45.85, 41.75, 54.35]
task3_accs = [0, 0, 0]
task4_accs = [0, 0]
task5_accs = [51.65]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/cifar10_gss_200.png')

plt.show()

print('Forgetting:', 2.46)
# Out:
# Forgetting: 2.46

# %% [markdown]
# #### Buffer Size = 500

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [98.7, 96.0, 97.8, 97.85, 97.39]
task2_accs = [0, 0, 0, 0]
task3_accs = [0, 0, 0]
task4_accs = [0, 0]
task5_accs = [0]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/cifar10_gss_500.png')

plt.show()

print('Forgetting:', 0.32)
# Out:
# Forgetting: 0.32

# %% [markdown]
# #### Buffer Size = 5120

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [99.1, 98.15, 98.55, 98.7, 98.8]
task2_accs = [0, 0, 0, 0]
task3_accs = [0, 0, 0]
task4_accs = [0, 0]
task5_accs = [0]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/cifar10_gss_5120.png')

plt.show()

print('Forgetting:', 0.074)
# Out:
# Forgetting: 0.074
