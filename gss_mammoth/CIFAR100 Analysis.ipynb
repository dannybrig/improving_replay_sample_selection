# %% [markdown]
# ### DER via GSS -- Class-IL Split-CIFAR100

# %% [markdown]
# #### Buffer Size = 200

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [88.0, 4.0, 4.5, 6.7, 1.7, 3.0, 2.1, 2.19, 0.6, 3.3]
task2_accs = [82.6, 18.5, 15.2, 15.2, 14.4, 16.3, 8.6, 12.1, 11.2]
task3_accs = [88.4, 26.3, 18.5, 22.1, 14.6, 12.8, 18.09, 13.6]
task4_accs = [79.7, 0.2, 0, 0, 0, 0, 0]
task5_accs = [82.5, 0, 0, 0, 0, 0]
task6_accs = [74.9, 0, 0, 0, 0]
task7_accs = [76.9, 0, 0, 0]
task8_accs = [78.6, 0, 0]
task9_accs = [83.3, 0]
task10_accs = [71.0]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/cifar100_gss_200.png')

plt.show()

print('Forgetting:', 78.53)
# Out:
# Forgetting: 78.53

# %% [markdown]
# #### Buffer Size = 500

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [87.8, 10.4, 12.6, 9.4, 10.6, 9.2, 6.6, 9.2, 10.8, 12.2]
task2_accs = [85.6, 32.5, 35.5, 30.8, 35.19, 24.7, 21.8, 25.8, 28.2]
task3_accs = [84.0, 19.8, 12.5, 14.4, 9.6, 5.8, 7.7, 11.8]
task4_accs = [75.6, 0, 0, 0, 0, 0, 0]
task5_accs = [76.1, 0, 0, 0, 0, 0]
task6_accs = [80.1, 0.1, 0, 0, 0]
task7_accs = [81.39, 0, 0, 0]
task8_accs = [80.7, 17.8, 13.2]
task9_accs = [75.9, 0]
task10_accs = [77.2]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/cifar100_gss_500.png')

plt.show()

print('Forgetting:', 73.51)
# Out:
# Forgetting: 73.51

# %% [markdown]
# #### Buffer Size = 5120

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [89.7, 55.7, 59.8, 57.09, 55.6, 41.5, 54.9, 55.8, 56.3, 56.6]
task2_accs = [76.6, 20.7, 22.9, 22.6, 17.8, 25.3, 22.9, 20.0, 23.2]
task3_accs = [42.6, 0, 0, 0.1, 0, 0, 0, 0]
task4_accs = [46.0, 0, 0.2, 0, 0, 0.1, 0.1]
task5_accs = [38.7, 0, 0, 0, 0, 0]
task6_accs = [86.4, 13.0, 10.0, 9.5, 8.5]
task7_accs = [61.9, 0, 0, 0]
task8_accs = [61.8, 0, 0]
task9_accs = [57.5, 0]
task10_accs = [64.1]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/cifar100_gss_5120.png')

plt.show()

print('Forgetting:', 52.54)
# Out:
# Forgetting: 52.54

# %% [markdown]
# ### ER via GSS -- Class-IL Split-CIFAR100

# %% [markdown]
# #### Buffer Size = 200

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [85.0, 27.8, 27.5, 30.2, 25.8, 30.5, 27.5, 27.1, 22.1, 26.1]
task2_accs = [54.89, 0, 0, 0, 0, 0, 0, 0, 0]
task3_accs = [87.2, 0.1, 0, 0, 0, 0, 0, 0]
task4_accs = [87.9, 0, 0, 0, 0, 0, 0]
task5_accs = [88.4, 0.1, 0, 0, 0, 0]
task6_accs = [89.1, 2.3, 0.2, 0, 0]
task7_accs = [87.8, 0, 0, 0]
task8_accs = [88.3, 0.1, 0]
task9_accs = [91.1, 0]
task10_accs = [93.4]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/cifar100_gss_200.png')

plt.show()

print('Forgetting:', 84.84)
# Out:
# Forgetting: 84.84

# %% [markdown]
# #### Buffer Size = 500

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [84.0, 46.0, 45.1, 44, 40.69, 42.3, 46.1, 43.6, 37.1, 41.3]
task2_accs = [84.1, 0.1, 0, 0, 0, 0, 0, 0, 0]
task3_accs = [86.1, 0.4, 0, 0, 0, 0, 0, 0]
task4_accs = [86.8, 0, 0, 0, 0, 0, 0]
task5_accs = [87.8, 0.2, 0, 0, 0, 0]
task6_accs = [88.7, 1.5, 0, 0, 0]
task7_accs = [88.0, 0, 0, 0]
task8_accs = [87.7, 0.3, 0]
task9_accs = [90.9, 0]
task10_accs = [93.1]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/cifar100_gss_500.png')

plt.show()

print('Forgetting:', 82.53)
# Out:
# Forgetting: 82.53

# %% [markdown]
# #### Buffer Size = 5120

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [87.5, 82.39, 82.0, 80.9, 80.7, 82.8, 80.5, 81.1, 82.6, 80.0]
task2_accs = [82.5, 0, 0, 0, 0, 0, 0, 0, 0]
task3_accs = [85.1, 0, 0, 0, 0, 0, 0, 0]
task4_accs = [85.3, 0.3, 0, 0, 0, 0, 0]
task5_accs = [84.7, 0.5, 0, 0, 0, 0]
task6_accs = [86.9, 0.8, 0.8, 0, 0]
task7_accs = [86.7, 0.5, 0, 0]
task8_accs = [87.6, 0.1, 0.2]
task9_accs = [89.0, 0.2]
task10_accs = [91.7]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/cifar100_gss_5120.png')

plt.show()

print('Forgetting:', 77.21)
# Out:
# Forgetting: 77.21

# %% [markdown]
# ### ER-ACE via GSS -- Class-IL Split CIFAR100

# %% [markdown]
# #### Buffer Size = 200

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [89.0, 79.6, 76.9, 76.4, 77.4, 77.9, 73.9, 73.2, 73.1, 74.1]
task2_accs = [19.2, 1.0, 0, 0, 0, 0, 0, 0, 0]
task3_accs = [21.3, 0.4, 0, 0, 0, 0, 0, 0]
task4_accs = [18.2, 0, 0.1, 0, 0, 0, 0]
task5_accs = [8.7, 0, 0, 0, 0, 0]
task6_accs = [6.0, 0.2, 0, 0, 0]
task7_accs = [0, 0, 0, 0]
task8_accs = [0, 0, 0]
task9_accs = [0, 0]
task10_accs = [0]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/cifar100_gss_200.png')

plt.show()

print('Forgetting:', 9.822)
# Out:
# Forgetting: 9.822

# %% [markdown]
# #### Buffer Size = 500

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [87.4, 83.0, 83.1, 80.8, 82.1, 83.7, 80.2, 84.2, 82.5, 82.5]
task2_accs = [20.7, 2.7, 0, 0, 0, 0, 0, 0, 0]
task3_accs = [17.1, 0.89, 0, 0, 0, 0, 0, 0]
task4_accs = [18.0, 0.2, 0.2, 0, 0, 0, 0]
task5_accs = [10.4, 0, 0, 0, 0, 0]
task6_accs = [5.6, 0, 0, 0, 0]
task7_accs = [0.1, 0, 0, 0]
task8_accs = [0, 0, 0]
task9_accs = [0, 0]
task10_accs = [0]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/cifar100_gss_500.png')

plt.show()

print('Forgetting:', 8.53)
# Out:
# Forgetting: 8.53

# %% [markdown]
# #### Buffer Size = 5120

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [88.7, 89.9, 92.3, 91.6, 92.7, 92.4, 92.7, 92.3, 91.9, 92.5]
task2_accs = [13.5, 0.8, 0.1, 0, 0, 0, 0, 0, 0]
task3_accs = [15.0, 0.1, 0, 0, 0, 0, 0, 0]
task4_accs = [10.5, 0, 0.1, 0, 0, 0, 0]
task5_accs = [4.8, 0.2, 0, 0, 0, 0]
task6_accs = [3.5, 0, 0, 0, 0]
task7_accs = [0.4, 0, 0, 0]
task8_accs = [0, 0, 0]
task9_accs = [0, 0]
task10_accs = [0]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/cifar100_gss_5120.png')

plt.show()

print('Forgetting:', 5.322)
# Out:
# Forgetting: 5.322
