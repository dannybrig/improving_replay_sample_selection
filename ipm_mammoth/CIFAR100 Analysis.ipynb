# %% [markdown]
# ### DER via IPM -- Class-IL Split-CIFAR100

# %% [markdown]
# #### Buffer Size = 200

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [90, 74.6, 71.7, 55.1, 44.9, 26.5, 25.5, 18.3, 10.4, 13.60]
task2_accs = [74.6, 61.3, 55.30, 44.3, 32.2, 30.7, 22.2, 15.5, 19.40]
task3_accs = [35.8, 63.3, 52.8, 40.5, 37.5, 29.59, 19.00, 25.6]
task4_accs = [41.19, 59.3, 38.2, 33.6, 29.09, 17.7, 17.4]
task5_accs = [51.3, 46.9, 42.4, 33.8, 25.0, 26.9]
task6_accs = [80.10, 54.1, 39.6, 30.9, 31.0]
task7_accs = [76.7, 58.19, 41.4, 43.5]
task8_accs = [78.4, 59.49, 50.3]
task9_accs = [88.2, 60.0]
task10_accs = [72.6]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/cifar100_ipm_200.png')

plt.show()


print('Forgetting:', 40.18)
# Out:
# Forgetting: 40.18

# %% [markdown]
# #### Buffer Size = 500

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [87.4, 79.7, 75.0, 65.0, 50.7, 36.8, 31.9, 32.80, 21.4, 16.0]
task2_accs = [59.0, 66.10, 55.40, 45.1, 43.4, 34.8, 29.2, 26.9, 21.7]
task3_accs = [33.2, 65.7, 61.5, 56.99, 54.2, 47.4, 44.9, 38.9]
task4_accs = [25.3, 67.7, 57.8, 51.0, 49.5, 39.5, 30.3]
task5_accs = [34, 62.5, 54.80, 49.5, 46.4, 42.0]
task6_accs = [53.90, 59.0, 51.7, 51.0, 42.60]
task7_accs = [52.60, 50.6, 46.0, 29.59]
task8_accs = [62.8, 58.69, 48.69]
task9_accs = [62.8, 70.7]
task10_accs = [60.6]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/cifar100_ipm_500.png')

plt.show()

print('Forgetting:', 28.22)
# Out:
# Forgetting: 28.22

# %% [markdown]
# #### Buffer Size = 5120

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [88.4, 87.9, 84.1, 78.1, 74.2, 64.9, 62.2, 60.4, 58.5, 57.49]
task2_accs = [31.8, 73.8, 70.89, 65.4, 64.4, 59.9, 57.59, 53.80, 52.5]
task3_accs = [23.40, 70.6, 70.0, 70.8, 68.0, 65.7, 63.4, 63.7]
task4_accs = [31.6, 69.5, 69.6, 67.80, 67.0, 62.1, 63.5]
task5_accs = [35.0, 65.3, 62.8, 61.0, 56.69, 61.6]
task6_accs = [45.1, 66.2, 63.80, 63.6, 64.5]
task7_accs = [39.7, 61.9, 63.1, 52.40]
task8_accs = [38.3, 52.80, 52.40]
task9_accs = [65, 62]
task10_accs = [33.5]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/cifar100_ipm_5120.png')

plt.show()

print('Forgetting:', 8.24)
# Out:
# Forgetting: 8.24

# %% [markdown]
# #### Intracluster Variance

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [89.4, 84.5, 80.5, 74.7, 71.89, 65, 61.8, 59.8, 60.89, 59.69]
task2_accs = [52.0, 67.30, 67.7, 62.6, 60.5, 58.8, 55.3, 55.1, 53.7]
task3_accs = [22.2, 72.6, 72.6, 70.3, 69.89, 64.9, 66.1, 67.6]
task4_accs = [17.9, 70.7, 69.69, 67.5, 67.7, 64.7, 62.5]
task5_accs = [17.29, 62.8, 65.2, 65.1, 61.5, 62.4]
task6_accs = [47.5, 67.2, 64.8, 67.5, 68.3]
task7_accs = [43.9, 62.7, 66.4, 66.2]
task8_accs = [44.2, 45.5, 50.1]
task9_accs = [46, 54]
task10_accs = [34]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))

axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/cifar100_ipm_intracluster_variance.png')

plt.show()

print('Forgetting:', )
# Out:
# Forgetting:

# %% [markdown]
# #### Kaiser Criterion

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [88.4, 73.2, 77.3, 72.5, 63.2, 52.8, 49.4, 46.2, 44.7, 47.4]
task2_accs = [67.7, 66.8, 64.4, 59.9, 55.2, 56.8, 55.8, 48.9, 47.9]
task3_accs = [38.7, 69.89, 65.3, 63.3, 59.8, 56.8, 57.9, 56.9]
task4_accs = [40.2, 72.89, 67.1, 64.6, 62.4, 61.1, 57.59]
task5_accs = [38.1, 62.2, 60.9, 57.59, 57.69, 57.4]
task6_accs = [58.3, 69.6, 64.1, 64.60, 61.7]
task7_accs = [45.7, 62.9, 63, 63.6]
task8_accs = [48.5, 54.6, 50.3]
task9_accs = [49.9, 58.5]
task10_accs = [39.1]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/cifar100_ipm_kaiser_criterion.png')

plt.show()

print('Forgetting:', 11.84)
# Out:
# Forgetting: 11.84

# %% [markdown]
# ### ER via IPM -- Class-IL Split-CIFAR100

# %% [markdown]
# #### Buffer Size = 200

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [84.7, 24.5, 13.5, 10.4, 6.6, 3, 2.6, 1.79, 1, 1.79]
task2_accs = [82.5, 26.7, 9.9, 8.7, 7.7, 7.1, 3.3, 0.7, 0.6]
task3_accs = [85.5, 28.00, 15.6, 15.4, 12.3, 8, 5.8, 4.3]
task4_accs = [86.7, 17.2, 8.7, 7.0, 4.3, 2.6, 2]
task5_accs = [87.7, 23.4, 15.5, 10.1, 5.3, 5.6]
task6_accs = [87.3, 23.2, 12.5, 6.6, 5.5]
task7_accs = [86.9, 18.8, 14.6, 11.5]
task8_accs = [86.4, 27.9, 12.7]
task9_accs = [89.1, 10.1]
task10_accs = [92.4]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/cifar100_ipm_200.png')

plt.show()

print('Forgetting:', 80.23)
# Out:
# Forgetting: 80.23

# %% [markdown]
# #### Buffer Size = 500

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [87.7, 49.5, 34.8, 29.79, 19, 16.1, 13.4, 12.7, 7.19, 7.6]
task2_accs = [83.3, 41.6, 20.59, 16.8, 14.2, 11.7, 12.5, 6.8, 6.1]
task3_accs = [86.6, 46.7, 28.2, 29.7, 24.6, 19, 14.7, 13.4]
task4_accs = [86.4, 33, 25, 20.7, 18.9, 12.9, 9.1]
task5_accs = [88.2, 36.19, 31.4, 26.8, 20.2, 14.8]
task6_accs = [88.6, 41.8, 33, 24, 15.4]
task7_accs = [88, 18.2, 16.4, 8.3]
task8_accs = [87.4, 35, 19.5]
task9_accs = [89.7, 38.6]
task10_accs = [92.5]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/cifar100_ipm_500.png')

plt.show()

print('Forgetting:', 72.55)
# Out:
# Forgetting: 72.55

# %% [markdown]
# #### Buffer Size = 5120

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [87.1, 82.1, 76, 69.5, 63.8, 58.59, 58.9, 52.2, 46.9, 46.2]
task2_accs = [81.3, 73.2, 61.5, 57.49, 53, 52.8, 49.1, 44.6, 41]
task3_accs = [83.3, 72.89, 66.1, 63.9, 58.4, 54.90, 52.30, 51.6]
task4_accs = [83, 65.4, 61.1, 57.0, 55.3, 50.3, 42.5]
task5_accs = [83.7, 64.9, 60.0, 54.3, 52.3, 44.4]
task6_accs = [86, 66.9, 60, 56.8, 50.4]
task7_accs = [85.7, 56.6, 56.9, 48.9]
task8_accs = [84.1, 62.4, 48.6]
task9_accs = [85.6, 61.3]
task10_accs = [88.5]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/cifar100_ipm_5120.png')

plt.show()

print('Forgetting:', 36.11)
# Out:
# Forgetting: 36.11

# %% [markdown]
# #### Intracluster Variance

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [86.5, 63.2, 56.39, 53.8, 50.6, 49.3, 50.1, 48.8, 47.9, 48.19]
task2_accs = [83.7, 59.8, 51.7, 50.6, 49.5, 49.3, 44.6, 43.2, 41]
task3_accs = [85.9, 67.88, 59.3, 61.4, 58.4, 54.1, 54.5, 53.6]
task4_accs = [83.39, 64.7, 56.8, 54.2, 51.2, 49.8, 43.9]
task5_accs = [84.2, 62.1, 57.9, 55.7, 52, 47.8]
task6_accs = [84.5, 69.19, 60, 57.69, 52.6]
task7_accs = [83.39, 60.89, 58.69, 54.80]
task8_accs = [80.68, 63.5, 50.5]
task9_accs = [84.39, 65.2]
task10_accs = [85.8]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/cifar100_ipm_intracluster_variance.png')

plt.show()

print('Forgetting:', 33.22)
# Out:
# Forgetting: 33.22

# %% [markdown]
# #### Kaiser Criterion

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [86.8, 47.3, 42.5, 42, 38.3, 35.5, 37.9, 36.3, 34.1, 33.3]
task2_accs = [83.2, 51.9, 40.40, 40.2, 38, 37.9, 34.4, 33.5, 33.7]
task3_accs = [85.39, 57.49, 48.6, 49.8, 44.5, 41.8, 41.3, 40.4]
task4_accs = [86.2, 52.5, 47.9, 42.9, 43.1, 40.30, 34.60]
task5_accs = [85.3, 55.60, 51.9, 47.69, 43.5, 40.2]
task6_accs = [85.7, 62.6, 55.3, 52.4, 44.1]
task7_accs = [85.8, 46.7, 50.3, 42.8]
task8_accs = [85, 58.09, 44.9]
task9_accs = [87.3, 60]
task10_accs = [88.8]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/cifar100_ipm_kaiser_criterion.png')

plt.show()

print('Forgetting:', 44.11)
# Out:
# Forgetting: 44.11

# %% [markdown]
# ### ER-ACE via IPM --Class-IL Split-CIFAR100

# %% [markdown]
# #### Buffer Size = 200

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [88.4, 79.7, 58.8, 41, 37.1, 31.6, 26.2, 26.3, 19, 19.1]
task2_accs = [18, 64.9, 52, 36, 30.5, 26.7, 18.3, 18, 18.5]
task3_accs = [24.6, 58.5, 49.6, 40.1, 39.5, 26.1, 27.1, 27.7]
task4_accs = [28.7, 61, 45.1, 40.2, 30.4, 26.6, 20.9]
task5_accs = [25.8, 54.3, 44.9, 36.9, 33.4, 35]
task6_accs = [19.5, 47.0, 39.8, 32.8, 33]
task7_accs = [13, 67, 47.6, 48]
task8_accs = [2.5, 49.3, 46.2]
task9_accs = [1.9, 38.8]
task10_accs = [0]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/cifar100_ipm_200.png')

plt.show()

print('Forgetting:', 26.91)
# Out:
# Forgetting: 26.91

# %% [markdown]
# #### Buffer Size = 500

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [88.9, 83.89, 65.1, 53.6, 46.4, 40.69, 35.9, 32.5, 35.09, 33.7]
task2_accs = [18.7, 70.19, 62.3, 49.9, 43.5, 32.8, 34.6, 31.4, 25.1]
task3_accs = [28.9, 65.9, 57.4, 47.59, 41.8, 40.3, 38.5, 31.2]
task4_accs = [24.4, 62.1, 54.8, 48.6, 43.3, 38.4, 38.5]
task5_accs = [20.1, 59.5, 50, 46, 41.8, 39]
task6_accs = [15.1, 53.6, 53.3, 51.1, 46.7]
task7_accs = [14.4, 50.9, 33.4, 24.0]
task8_accs = [3.4, 52, 46.9]
task9_accs = [2.1, 66.2]
task10_accs = [0]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/cifar100_ipm_500.png')

plt.show()

print('Forgetting:', 24.21)
# Out:
# Forgetting: 24.21

# %% [markdown]
# #### Buffer Size = 5120

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [88.9, 89.9, 83.6, 75.2, 71.3, 69.3, 63.9, 62, 63.1, 60.0]
task2_accs = [11.5, 79.3, 73.4, 66.1, 60.6, 56.4, 56.5, 53.9, 51.9]
task3_accs = [12.8, 78, 73.7, 67.9, 65.9, 64.6, 64, 62.5]
task4_accs = [15.5, 75.8, 72.3, 64.3, 62, 56.4, 58.8]
task5_accs = [11.7, 71.5, 65, 62, 57.9, 56.1]
task6_accs = [8.4, 71.8, 66.7, 66.3, 60.6]
task7_accs = [5, 70.5, 65.4, 62.9]
task8_accs = [1.6, 62.4, 59.0]
task9_accs = [0.8, 72.1]
task10_accs = [0]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/cifar100_ipm_5120.png')

plt.show()

print('Forgetting:', 14.12)
# Out:
# Forgetting: 14.12

# %% [markdown]
# #### Intracluster Variance

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [88.3, 86.3, 78.5, 71.2, 66.9, 63.7, 60.8, 60.89, 58.59, 58.19]
task2_accs = [16.2, 76.2, 70.7, 62.4, 60.9, 55.90, 54.50, 52.2, 51]
task3_accs = [17.59, 76.4, 73.1, 70, 67.1, 64.4, 65.2, 64]
task4_accs = [18.8, 74.8, 69.1, 65.7, 61.7, 60.5, 59.5]
task5_accs = [12, 72.6, 65.9, 65.2, 62.9, 59.9]
task6_accs = [9.9, 73, 68.1, 64.8, 62.1]
task7_accs = [5.7, 70.5, 63.2, 63.6]
task8_accs = [2, 66.5, 63]
task9_accs = [0.3, 71.1]
task10_accs = [0]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/cifar100_ipm_intracluster_variance.png')

plt.show()

print('Forgetting:', 13)
# Out:
# Forgetting: 13

# %% [markdown]
# #### Kaiser Criterion

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [88.7, 83.8, 72.2, 65.4, 58.8, 55.3, 52.3, 52.7, 51.2, 48.6]
task2_accs = [13.7, 73.1, 66.6, 56.8, 53.8, 49.9, 48, 47.89, 46.40]
task3_accs = [25.1, 68.5, 66.7, 61.5, 57.9, 55.2, 53.5, 51.5]
task4_accs = [22.7, 75.4, 65.2, 61.4, 56.9, 54.98, 50.7]
task5_accs = [16.5, 68, 62, 58.19, 55.7, 53]
task6_accs = [12.6, 68.7, 65.4, 62.3, 59.59]
task7_accs = [9.3, 66.8, 61, 57.9]
task8_accs = [2.7, 63.7, 59.89]
task9_accs = [2.1, 72.1]
task10_accs = [0]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/cifar100_ipm_kaiser_criterion.png')

plt.show()

print('Forgetting:', 16.23)
# Out:
# Forgetting: 16.23
