# %% [markdown]
# ### DER via IPM -- Class-IL Split-CIFAR10

# %% [markdown]
# #### Buffer Size = 200

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [98.55, 97.7, 90.0, 83.3, 55.85]
task2_accs = [0.0, 76.35, 45.15, 30.5]
task3_accs = [1.2, 76.8, 49.25]
task4_accs = [7.95, 83.0]
task5_accs = [85.8]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/cifar10_ipm_200.png')

plt.show()

print('Forgetting:', 29.0250)
# Out:
# Forgetting: 29.025

# %% [markdown]
# #### Buffer Size = 500

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [98.4, 98.05, 93.89, 91.2, 76.55]
task2_accs = [0.0, 74.45, 53.0, 37.7]
task3_accs = [7.64, 80.05, 63.25]
task4_accs = [14.7, 90.0]
task5_accs = [45.8]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/cifar10_ipm_500.png')

plt.show()

print('Forgetting:', 18.85)
# Out:
# Forgetting: 18.85

# %% [markdown]
# #### Buffer Size = 5120

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [98.6, 98.6, 97.1, 96.7, 92.45]
task2_accs = [0.0, 81.25, 73.05, 71.35]
task3_accs = [0.4, 79.55, 77.1]
task4_accs = [9.75, 90.75]
task5_accs = [4.2]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/cifar10_ipm_5120.png')

plt.show()

print('Forgetting:', 4.624)
# Out:
# Forgetting: 4.624

# %% [markdown]
# #### Intracluster Variance

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [98.3, 97.85, 97.6, 94.5, 75.5]
task2_accs = [0.15, 56.0, 46.4, 42.5]
task3_accs = [18.95, 82.1, 60.09]
task4_accs = [2.5, 89.35]
task5_accs = [59.19]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/cifar10_ipm_intracluster_variance.png')

plt.show()

print('Forgetting:', 14.57)
# Out:
# Forgetting: 14.57

# %% [markdown]
# #### Kaiser Criterion

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [98.75, 88.85, 79.7, 81.6, 59.55]
task2_accs = [49.25, 36.4, 36.55, 48.15]
task3_accs = [95.3, 60.45, 74.6]
task4_accs = [98.5, 88.25]
task5_accs = [97]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/cifar10_ipm_kaiser_criterion.png')

plt.show()

print('Forgetting:', 17.8125)
# Out:
# Forgetting: 17.8125

# %% [markdown]
# ### ER Via IPM -- Class-IL Split-CIFAR10

# %% [markdown]
# #### Buffer Size = 200

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [98.55, 67.2, 68.35, 60.75, 11.35]
task2_accs = [91.05, 14.95, 9.75, 18.6]
task3_accs = [98.89, 29.84, 50.5]
task4_accs = [98.65, 73.1]
task5_accs = [97.5]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/cifar10_ipm_200.png')

plt.show()

print('Forgetting:', 57.65)
# Out:
# Forgetting: 57.65

# %% [markdown]
# #### Buffer Size = 500

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [98.25, 80.85, 77.64, 76.35, 31.2]
task2_accs = [91.5, 28.95, 22.0, 36.3]
task3_accs = [95.7, 37.75, 60.45]
task4_accs = [98.6, 82.6]
task5_accs = [97.45]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/cifar10_ipm_500.png')

plt.show()

print('Forgetting:', 43.375)
# Out:
# Forgetting: 43.375

# %% [markdown]
# #### Buffer Size = 5120

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [98.65, 97.85, 95.8, 94.55, 81.8]
task2_accs = [85.3, 76.9, 65.10, 70.39]
task3_accs = [83.85, 76.85, 81.89]
task4_accs = [96.8, 91.2]
task5_accs = [96.3]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/cifar10_ipm_5120.png')

plt.show()

print('Forgetting:', 9.825)
# Out:
# Forgetting: 9.825

# %% [markdown]
# #### Intracluster Variance

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [82.75, 67.05, 69.8, 73, 45.95]
task2_accs = [92.7, 21.65, 24.15, 39.95]
task3_accs = [95.6, 46.65, 63.80]
task4_accs = [98.55, 84.89]
task5_accs = [97.39]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/cifar10_ipm_intracluster_variance.png')

plt.show()

print('Forgetting:', 33.75)
# Out:
# Forgetting: 33.75

# %% [markdown]
# #### Kasier Criterion

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [98.75, 88.85, 79.7, 71.6, 59.55]
task2_accs = [49.25, 36.4, 36.55, 48.15]
task3_accs = [95.3, 60.45, 74.6]
task4_accs = [98.5, 88.25]
task5_accs = [97]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/cifar10_ipm_kaiser_criterion.png')

plt.show()

print('Forgetting:', 17.8125)
# Out:
# Forgetting: 17.8125

# %% [markdown]
# ### GDumb via IPM -- Class -IL Split-CIFAR10

# %% [markdown]
# - GDumb has no task to task performance as each task only samples from a buffer and then we proceed to train on the Buffer Only

# %% [markdown]
# ### ER-ACE via IPM -- Class -IL Split-CIFAR10

# %% [markdown]
# #### Buffer Size = 200

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [98.95, 95, 90, 84.8, 73.9]
task2_accs = [0, 71.25, 50.05, 48.65]
task3_accs = [0, 72.8, 54.7]
task4_accs = [0, 71.7]
task5_accs = [0]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/cifar10_ipm_200.png')

plt.show()

print('Forgetting:', 16.4375)
# Out:
# Forgetting: 16.4375

# %% [markdown]
# #### Buffer Size = 500

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [98.9, 96.55, 92.35, 89.35, 77.7]
task2_accs = [0, 79.25, 59.15, 56.55]
task3_accs = [0, 76.7, 68.25]
task4_accs = [0, 81.1]
task5_accs = [0]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/cifar10_ipm_500.png')

plt.show()

print('Forgetting:', 13.08)
# Out:
# Forgetting: 13.08

# %% [markdown]
# #### Buffer Size = 5120

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [98.6, 98.4, 95.6, 96.45, 91.55]
task2_accs = [0, 88.35, 80.4, 72.35]
task3_accs = [0, 81.25, 81.65]
task4_accs = [0, 90.6]
task5_accs = [0]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/cifar10_ipm_5120.png')

plt.show()

print('Forgetting:', 5.762)
# Out:
# Forgetting: 5.762

# %% [markdown]
# #### Intracluster Variance

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [98.9, 96.3, 91.8, 91.25, 79.9]
task2_accs = [0, 76.75, 59.19, 54.55]
task3_accs = [0, 76.64, 64.14]
task4_accs = [0, 87.05]
task5_accs = [0]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/cifar10_ipm_intracluster_variance.png')

plt.show()

print('Forgetting:', 13.425)
# Out:
# Forgetting: 13.425

# %% [markdown]
# #### Kaiser Criterion

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [98.6, 96.89, 95.5, 94.25, 84.6]
task2_accs = [0, 78.25, 66.75, 63.74]
task3_accs = [0, 79.9, 74.4]
task4_accs = [0, 86.6]
task5_accs = [0]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/cifar10_ipm_kaiser_criterion.png')

plt.show()
print('Forgetting:', 8.5)
# Out:
# Forgetting: 8.5
