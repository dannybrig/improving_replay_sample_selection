# %% [markdown]
# ### DER via IPM -- Class-IL Split-TinyImageNet

# %% [markdown]
# #### Buffer Size = 200

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [76.9, 61.7, 55.5, 42.19, 38.9, 22.40, 9.1, 12.9, 8.0, 8.4]
task2_accs = [45.80, 36.8, 26.9, 23.1, 17.9, 6.8, 10.0, 6.6, 5.6]
task3_accs = [20.8, 32.5, 27.7, 21.6, 9.2, 14.00, 11.0, 8.7]
task4_accs = [43.1, 34.4, 27.9, 8.3, 13.10, 9.4, 8.0]
task5_accs = [43.8, 51.1, 17.9, 20.7, 13.8, 9.4]
task6_accs = [48.9, 30.4, 24.3, 18.4, 12.9]
task7_accs = [77.4, 40.30, 27.0, 14.00]
task8_accs = [64.5, 30.2, 13.90]
task9_accs = [65.3, 22.90]
task10_accs = [75.5]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/tinyimg_ipm_200.png')

plt.show()

print('Forgetting:', 44.63)
# Out:
# Forgetting: 44.63

# %% [markdown]
# #### Buffer Size = 500

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [78.2, 65.0, 63.6, 55.60, 50.3, 44.1, 34.9, 32.3, 27.3, 21.0]
task2_accs = [43.9, 47.09, 41.3, 36.3, 28.7, 24.0, 21.09, 20.7, 13.8]
task3_accs = [5.8, 42.3, 39.6, 36.9, 32.5, 30.2, 27.5, 16.5]
task4_accs = [22.0, 39.5, 36.3, 29.2, 27.4, 25.7, 17.9]
task5_accs = [17.2, 33.0, 22.3, 24.2, 23.0, 14.09]
task6_accs = [24.8, 12.1, 7.9, 3.9, 2.6]
task7_accs = [53.1, 41.69, 31.7, 16.6]
task8_accs = [53.5, 30.2, 20.20]
task9_accs = [42.69, 38.9]
task10_accs = [54.30]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/tinyimg_ipm_500.png')

plt.show()

print('Forgetting:', 28.06)
# Out:
# Forgetting: 28.06

# %% [markdown]
# #### Buffer Size = 5120

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [80.4, 79.2, 75.1, 72.1, 66.1, 67.30, 63.4, 62.1, 58.4, 55.1]
task2_accs = [1.3, 53.6, 51.80, 45.80, 45.4, 46.5, 42.4, 43.4, 38.2]
task3_accs = [1.2, 50.7, 51.1, 49.6, 51.2, 50.8, 50.4, 47.3]
task4_accs = [9.0, 45.1, 46.7, 45.7, 46.7, 45.7, 45.2]
task5_accs = [17.2, 28.7, 32.6, 34.9, 35.5, 37.3]
task6_accs = [16.8, 22.0, 29.7, 29.4, 30.59]
task7_accs = [32.0, 28.99, 29.9, 27.7]
task8_accs = [28.0, 21.2, 24.7]
task9_accs = [14.89, 13.3]
task10_accs = [17.1]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/tinyimg_ipm_5120.png')

plt.show()

print('Forgetting:', 6.14)
# Out:
# Forgetting: 6.14

# %% [markdown]
# #### Intracluster Variance

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [80.3, 77.3, 74, 62.9, 71.3, 69.39, 51.6, 67.2, 64.5, 65.1]
task2_accs = [13.1, 53.9, 55.8, 53.9, 52.6, 49.4, 51, 52.2, 47.19]
task3_accs = [5.89, 41.9, 46.2, 49.2, 58.3, 55.1, 54.3, 51.9]
task4_accs = [10.9, 34.5, 42.5, 50.9, 49.6, 54.1, 48.3]
task5_accs = [5.3, 14.4, 32.7, 29.7, 34.9, 32.9]
task6_accs = [9.8, 20.7, 14.49, 20, 17.8]
task7_accs = [59.4, 24.8, 25.6, 19.7]
task8_accs = [22.7, 9.5, 10.8]
task9_accs = [12.5, 3.5]
task10_accs = [34]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/tinyimg_ipm_intracluster_variance.png')

plt.show()

print('Forgetting:', 11.27)
# Out:
# Forgetting: 11.27

# %% [markdown]
# #### Kaiser Criterion

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [72.89, 74.5, 70.1, 66.3, 63.4, 61.4, 56.8, 54.4, 56.3, 52.8]
task2_accs = [18.6, 51.4, 48.9, 45, 40.5, 36.3, 39.3, 39.8, 36.6]
task3_accs = [6, 50.4, 51.3, 49.7, 47.8, 52, 50.2, 50]
task4_accs = [8.1, 43.7, 44, 44.5, 48.6, 47.8, 47.8]
task5_accs = [4.1, 22.6, 29.8, 32.8, 35.19, 35.69]
task6_accs = [22.7, 20, 26.5, 29.59, 28.9]
task7_accs = [58.09, 29.5, 32.4, 29.7]
task8_accs = [18.4, 14.2, 19.3]
task9_accs = [15.1, 10.29]
task10_accs = [33.8]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/tinyimg_ipm_kaiser_criterion.png')

plt.show()

print('Forgetting:', 8.13)
# Out:
# Forgetting: 8.13

# %% [markdown]
# ### ER via IPM -- Class-IL Split-TinyImageNet

# %% [markdown]
# #### Buffer Size = 200

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [77.4, 13.2, 3.69, 1.5, 0.5, 0.5, 0.3, 0, 0, 0.1]
task2_accs = [70.6, 6.1, 2.9, 0.4, 0.1, 0, 0.1, 0, 0]
task3_accs = [78.1, 7.1, 1, 1.09, 0.3, 0.1, 0, 0.1]
task4_accs = [81.6, 5.8, 0.5, 0, 0, 0, 0]
task5_accs = [80, 6.5, 1.5, 0.6, 0.3, 0]
task6_accs = [77.7, 9, 3.4, 1.5, 0.5]
task7_accs = [79.3, 5.1, 1.09, 0.4]
task8_accs = [79, 5.2, 1.3]
task9_accs = [71.8, 2.1]
task10_accs = [80.8]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/tinyimg_ipm_200.png')

plt.show()

print('Forgetting:', 76.77)
# Out:
# Forgetting: 76.77

# %% [markdown]
# #### Buffer Size = 500

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [77.5, 28.49, 14.2, 8.7, 4.2, 2.4, 1.3, 1.4, 1.2, 0.2]
task2_accs = [70, 13.5, 4.8, 3.9, 2.5, 2.4, 1.6, 0.7, 1.2]
task3_accs = [77.2, 19.2, 7.9, 4.3, 4.5, 2.6, 2.19, 1.2]
task4_accs = [80.3, 14.2, 8.4, 4.9, 4.1, 3.5, 0.8]
task5_accs = [78.4, 7.8, 6.8, 3.3, 2.7, 1.7]
task6_accs = [78.6, 5.7, 2.3, 0, 0]
task7_accs = [79.4, 14.6, 7.0, 1.79]
task8_accs = [78.7, 8.5, 4.2]
task9_accs = [72, 8.3]
task10_accs = [80.3]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/tinyimg_ipm_500.png')

plt.show()

print('Forgetting:', 74.73)
# Out:
# Forgetting: 74.73

# %% [markdown]
# #### Buffer Size = 5120

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [78.2, 64.3, 51.7, 42.8, 36.19, 31.4, 26.5, 24.8, 21.3, 17.2]
task2_accs = [68.1, 45.6, 36.3, 27.4, 24.2, 19.9, 18.6, 14.89, 13.4]
task3_accs = [74.8, 52.2, 39.4, 30.9, 30.2, 25.7, 20.4, 19.5]
task4_accs = [77.5, 49.3, 39.6, 34.4, 30.09, 27.8, 23.5]
task5_accs = [75.8, 38.7, 33.2, 28.1, 23, 22.1]
task6_accs = [77.7, 38.1, 30.09, 26.4, 22.4]
task7_accs = [76, 39.1, 31.5, 24.09]
task8_accs = [75.3, 31.3, 24.9]
task9_accs = [70.6, 27.5]
task10_accs = [78.8]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/tinyimg_ipm_5120.png')

plt.show()

print('Forgetting:', 53.26)
# Out:
# Forgetting: 53.26

# %% [markdown]
# #### Intracluster Variance

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [77.8, 58.69, 52.88, 49.2, 46, 45.2, 42.8, 42.6, 42.6, 37.7]
task2_accs = [67.1, 49, 44.7, 41.3, 39.1, 37.7, 34.2, 33.7, 32.7]
task3_accs = [73, 56.8, 52.2, 48.1, 47.09, 44.3, 41.19, 39.4]
task4_accs = [76.1, 57.9, 51.8, 50.9, 48.6, 45.9, 44.2]
task5_accs = [71.6, 49.5, 47.9, 44.2, 41, 40]
task6_accs = [72.1, 51.7, 47, 44.4, 41.1]
task7_accs = [71.1, 52.5, 48.9, 43.2]
task8_accs = [69.3, 59.6, 44.4]
task9_accs = [62.5, 43.6]
task10_accs = [69.69]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/tinyimg_ipm_intracluster_variance.png')

plt.show()

print('Forgetting:', 30.4)
# Out:
# Forgetting: 30.4

# %% [markdown]
# #### Kaiser Criterion

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [76.6, 42.4, 35.6, 34.5, 28.9, 28.9, 26.3, 28.0, 26.2, 22.5]
task2_accs = [69.5, 34.2, 28.9, 26.4, 22.1, 24.3, 22.7, 20.3, 20]
task3_accs = [76.9, 46.1, 35.1, 31.6, 29.7, 28.0, 25.7, 25.5]
task4_accs = [77.4, 46.3, 37.5, 36, 35.5, 36.19, 32.1]
task5_accs = [75, 39.5, 35.6, 30.4, 27.8, 26.5]
task6_accs = [74.8, 39.2, 33.8, 32.9, 30.8]
task7_accs = [76.2, 41.9, 38.2, 31.6]
task8_accs = [72.39, 35.19, 32.5]
task9_accs = [70.5, 36.3]
task10_accs = [75.3]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/tinyimg_ipm_kaiser_criterion.png')

plt.show()

print('Forgetting:', 45.8)
# Out:
# Forgetting: 45.8

# %% [markdown]
# ### ER-ACE via IPM -- Class-IL Split-TinyImageNet

# %% [markdown]
# #### Buffer Size = 200

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [78.7, 58.9, 39.3, 30.3, 24.8, 13.5, 10.5, 7.5, 8.79, 8.9]
task2_accs = [33.80, 46.7, 30.5, 20.2, 12.5, 9.3, 7.5, 9.7, 11.3]
task3_accs = [40.69, 40.2, 32.7, 18.8, 11.2, 13.5, 14.09, 12.6]
task4_accs = [43.6, 43.3, 20.3, 17.2, 10.9, 13.9, 14.2]
task5_accs = [38.1, 51.5, 29.59, 24.9, 16.4, 14.0]
task6_accs = [32.5, 51.7, 33.1, 23.7, 20.8]
task7_accs = [28.4, 39.2, 26.9, 22.8]
task8_accs = [19, 32.5, 21.9]
task9_accs = [9.2, 24.6]
task10_accs = [0.3]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/tinyimg_ipm_200.png')

plt.show()

print('Forgetting:', 28.67)
# Out:
# Forgetting: 28.67

# %% [markdown]
# #### Buffer Size = 500

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [79.9, 68.8, 49.2, 42, 34.59, 26.5, 24.9, 15.5, 15.7, 13.9]
task2_accs = [24.4, 50.8, 37.5, 28.29, 25.4, 22, 17.9, 17.29, 14.6]
task3_accs = [32.9, 52, 41.8, 31.2, 28.9, 25, 21.7, 17]
task4_accs = [39.1, 51, 41.6, 38.6, 27.6, 25.6, 21.9]
task5_accs = [30, 47, 38.5, 30.4, 25.7, 19]
task6_accs = [28.4, 30.09, 18.8, 7.5, 5.6]
task7_accs = [23.59, 50, 34.4, 26.3]
task8_accs = [17, 36.9, 26.2]
task9_accs = [6.4, 44.8]
task10_accs = [0]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/tinyimg_ipm_500.png')

plt.show()

print('Forgetting:', 28.13)
# Out:
# Forgetting: 28.13

# %% [markdown]
# #### Buffer Size = 5120

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [80.4, 78.60, 68.7, 60.69, 56.0, 50.6, 47.0, 41.8, 41.3, 41.19]
task2_accs = [16.6, 61.7, 55.9, 46.1, 40, 38.3, 33.2, 31.4, 28.9]
task3_accs = [22.1, 63.4, 56.3, 52.3, 47.4, 42.4, 41.5, 39.4]
task4_accs = [26.3, 62.8, 57.59, 53.3, 47.0, 46.2, 43.4]
task5_accs = [15.2, 57.09, 51.4, 47.5, 42, 38.1]
task6_accs = [13.2, 53.7, 48.4, 42.3, 38]
task7_accs = [12.7, 54.2, 48.6, 44.1]
task8_accs = [7.19, 52.7, 45.3]
task9_accs = [1.7, 45.8]
task10_accs = [0]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/tinyimg_ipm_5120.png')

plt.show()

print('Forgetting:', 18.61)
# Out:
# Forgetting: 18.61

# %% [markdown]
# #### Intracluster Variance

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [76.9, 75.9, 67.7, 63.2, 59.59, 57.09, 54.8, 50, 51.3, 50.1]
task2_accs = [20.5, 60.69, 54.5, 48.8, 46.4, 44.4, 41.4, 39.8, 39.2]
task3_accs = [17.7, 64.5, 62.5, 58.59, 54.5, 51.2, 50.4, 49.1]
task4_accs = [20, 65.5, 62, 58.59, 52, 54.88, 52.9]
task5_accs = [12.4, 62.1, 56.39, 53.6, 50.4, 46.6]
task6_accs = [10.5, 58.4, 53, 50.5, 49.4]
task7_accs = [9.7, 56.8, 52.2, 50.3]
task8_accs = [3.3, 56.3, 50.6]
task9_accs = [0.4, 49.4]
task10_accs = [0]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/tinyimg_ipm_intracluster_variance.png')

plt.show()

print('Forgetting:', 12.56)
# Out:
# Forgetting: 12.56

# %% [markdown]
# #### Kaiser Criterion

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [80.1, 74.1, 65.6, 57.3, 52.8, 52.2, 47.5, 45.3, 43.1, 42]
task2_accs = [23.7, 57.4, 45.6, 40.4, 38.5, 35.3, 34.3, 32.2, 30.89]
task3_accs = [27.40, 62.8, 56.39, 53.9, 49.2, 47.3, 45.6, 44.3]
task4_accs = [26.9, 63.7, 59.4, 53.9, 49.4, 50.8, 48.1]
task5_accs = [16.3, 61.19, 51.7, 47.9, 44.5, 40.9]
task6_accs = [15.5, 57.69, 49.5, 45.8, 44.2]
task7_accs = [11.1, 53.5, 50.7, 45.9]
task8_accs = [7.0, 53.2, 48.4]
task9_accs = [1.09, 50.9]
task10_accs = [0]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/tinyimg_ipm_kaiser_criterion.png')

plt.show()

print('Forgetting:', 16.18)
# Out:
# Forgetting: 16.18
