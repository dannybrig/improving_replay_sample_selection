# %% [markdown]
# ### DER via Herding -- Class-IL Split-TinyImageNet

# %% [markdown]
# #### Buffer Size = 200

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [79, 0.4, 0.3, 1, 0.3, 0.1, 0, 0, 0, 0]
task2_accs = [74.1, 0.7, 1.2, 0.1, 0, 0, 0, 0, 0]
task3_accs = [81.3, 2.1, 0.1, 0, 0, 0, 0, 0]
task4_accs = [81.39, 1.9, 0, 0, 0, 0, 0]
task5_accs = [78.9, 0.2, 0, 0, 0, 0]
task6_accs = [74.8, 0, 0, 0, 0]
task7_accs = [70.19, 0.2, 0, 0]
task8_accs = [71.5, 0, 0]
task9_accs = [59, 0]
task10_accs = [69.39]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/tinyimg_herding_200.png')

plt.show()

print('Forgetting:', 74.46)
# Out:
# Forgetting: 74.46

# %% [markdown]
# #### Buffer Size = 500

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [79.9, 1.5, 2.9, 0.89, 0.3, 0.4, 0.1, 0, 0, 0]
task2_accs = [72.89, 3.5, 1.3, 0.3, 0, 0, 0, 0, 0]
task3_accs = [78.3, 1.4, 0.1, 0.1, 0, 0, 0, 0]
task4_accs = [80.2, 0.4, 0.1, 0, 0, 0, 0]
task5_accs = [76.5, 1, 0.1, 0, 0, 0]
task6_accs = [74.8, 0.3, 0, 0, 0]
task7_accs = [71, 0.1, 0, 0]
task8_accs = [60.09, 0, 0]
task9_accs = [24.9, 0]
task10_accs = [42.19]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/tinyimg_herding_500.png')

plt.show()

print('Forgetting:', 68.73)
# Out:
# Forgetting: 68.73

# %% [markdown]
# #### Buffer Size = 5120

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [75.2, 6.8, 2.3, 1, 0, 0.1, 2, 0, 1.09, 0]
task2_accs = [66.7, 15.7, 8.7, 4.7, 9.5, 10.9, 4.9, 7.0, 6.4]
task3_accs = [54.1, 9.3, 0.2, 1.6, 3.1, 0.1, 1.3, 1.5]
task4_accs = [71.3, 1, 0.1, 3.1, 4.1, 2.6, 3]
task5_accs = [21.9, 0.6, 4.3, 6.4, 0.1, 1.79]
task6_accs = [0.7, 9, 1.2, 1.7, 0.1]
task7_accs = [63.80, 15, 4.5, 1.3]
task8_accs = [20.7, 9.5, 4.3]
task9_accs = [35.3, 15.29]
task10_accs = [25.4]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/tinyimg_herding_5120.png')

plt.show()

print('Forgetting:', 42.68)
# Out:
# Forgetting: 42.68

# %% [markdown]
# #### Intracluster Variance

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [79.4, 1.5, 0.4, 0.3, 0.5, 0.1, 0.89, 0, 0.3, 0.3]
task2_accs = [71.39, 0.2, 0, 0, 0, 0, 0, 0, 0]
task3_accs = [75.3, 0, 0, 0, 0, 0, 0, 0]
task4_accs = [79.9, 0, 0, 0, 0, 0, 0]
task5_accs = [76, 0, 0, 0, 0, 0]
task6_accs = [80.1, 0, 0, 0, 0]
task7_accs = [77.5, 0, 0, 0]
task8_accs = [78.1, 0, 0]
task9_accs = [70, 0]
task10_accs = [81.2]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/tinyimg_herding_intracluster_variance.png')

plt.show()

print('Forgetting:', 76.37)
# Out:
# Forgetting: 76.37

# %% [markdown]
# #### Kaiser Criterion

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [81.39, 0.6, 0.5, 0, 0, 0.2, 0.3, 0.1, 0.7, 0.1]
task2_accs = [72.39, 0, 0, 0, 0, 0, 0, 0, 0]
task3_accs = [78.2, 0, 0, 0, 0, 0, 0, 0]
task4_accs = [28.49, 0, 0, 0, 0, 0, 0]
task5_accs = [26.40, 0, 0, 0, 0, 0]
task6_accs = [77.1, 0, 0, 0, 0]
task7_accs = [75.2, 0, 0, 0]
task8_accs = [76.1, 0, 0]
task9_accs = [65.2, 0]
task10_accs = [64.7]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/tinyimg_herding_kaiser_criterion.png')

plt.show()

print('Forgetting:', 64.48)
# Out:
# Forgetting: 64.48

# %% [markdown]
# ### ER via Herding -- Class-IL Split-TinyImageNet

# %% [markdown]
# #### Buffer Size = 200

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [78.3, 20.59, 7.19, 3.69, 2.4, 0.7, 0.3, 0.5, 0.8, 0.6]
task2_accs = [72.1, 9.1, 4.7, 1, 1.3, 0.5, 0.1, 0.2, 0.3]
task3_accs = [77, 14.09, 3.3, 3, 1.09, 0.3,  0.3, 0.3]
task4_accs = [82.19, 9.3, 4.39, 1.2, 1.2, 0.5, 0.4]
task5_accs = [81.2, 7.0, 2.19, 0.7, 0.89, 0.5]
task6_accs = [79.1, 2.5, 1, 0.4, 0.2]
task7_accs = [79.9, 5, 1.79, 0.6]
task8_accs = [80.2, 4.5, 2.6]
task9_accs = [73.8, 2.4]
task10_accs = [80.2]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/tinyimg_herding_200.png')

plt.show()

print('Forgetting:', 77.32)
# Out:
# Forgetting: 77.32

# %% [markdown]
# #### Buffer Size = 500

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [77.8, 32.80, 19.8, 12.3, 7.6, 4.7, 3.59, 2, 2.19, 0.7]
task2_accs = [71.3, 19.2, 9.4, 6, 4.2, 1.9, 1.2, 1.7, 1]
task3_accs = [79.8, 26.2, 10.4, 6, 4.2, 2.3, 1.4, 0.7]
task4_accs = [81, 20.9, 11.3, 5.7, 4.9, 3.2, 1.3]
task5_accs = [79.10, 11.7, 9.6, 4.8, 3.1, 1.9]
task6_accs = [79.60, 12.7, 5.89, 3.1, 1.2]
task7_accs = [80.2, 13.6, 8.1, 3]
task8_accs = [79.1, 12.2, 6.4]
task9_accs = [75, 4.7]
task10_accs = [81.8]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/tinyimg_herding_500.png')

plt.show()

print('Forgetting:', 75.77)
# Out:
# Forgetting: 75.77

# %% [markdown]
# #### Buffer Size = 5120

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [78.3, 64.5, 52.90, 46.9, 41.09, 33.3, 29.9, 28.2, 24.7, 19.1]
task2_accs = [67.7, 44.3, 32.9, 29.2, 22.6, 20, 18.5, 14.39, 13.8]
task3_accs = [75.1, 53.4, 40.6, 35.69, 32.3, 26.8, 20.59, 20.1]
task4_accs = [79.1, 51.2, 40.1, 34, 32.6, 29.7, 24.8]
task5_accs = [76.3, 39.1, 32.2, 28.2, 24.6, 21.3]
task6_accs = [76.8, 40.1, 30.7, 28.5, 23.7]
task7_accs = [76.4, 40.2, 32.4, 23]
task8_accs = [76.5, 36.1, 27.3]
task9_accs = [69.5, 27]
task10_accs = [77.1]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/tinyimg_herding_5120.png')

plt.show()

print('Forgetting:', 52.84)
# Out:
# Forgetting: 52.84

# %% [markdown]
# #### Intracluster Variance

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [76.9, 58.8, 54.3, 50.3, 49.5, 46.6, 46.5, 46, 44.3, 40.9]
task2_accs = [68.5, 50.1, 44.2, 39.9, 38.8, 38.2, 39.1, 34.5, 34.5]
task3_accs = [72.7, 58.8, 54, 48.1, 49.2, 56.6, 44.2, 42]
task4_accs = [75.7, 59, 54.2, 49.5, 50.1, 48.9, 47.4]
task5_accs = [72.1, 52.5, 51.2, 46.1, 43, 41.8]
task6_accs = [72.5, 52.6, 49.1, 45.4, 43.8]
task7_accs = [70.6, 53, 49.2, 44.3]
task8_accs = [69, 50.1, 45.2]
task9_accs = [62.1, 43.2]
task10_accs = [71.3]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/tinyimg_herding_intracluster_variance.png')

plt.show()

print('Forgetting:', 28.54)
# Out:
# Forgetting: 28.54

# %% [markdown]
# #### Kaiser Criterion

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [76.8, 45.6, 41.4, 39.2, 36.3, 33.6, 32.6, 33.8, 32.5, 27.3]
task2_accs = [70.3, 34.8, 30.7, 26.3, 25.9, 24.8, 24.7, 21.9, 23]
task3_accs = [77.6, 50.2, 42.4, 37.9, 36.3, 34.59, 31, 30.2]
task4_accs = [78.3, 47.8, 42.1, 40.2, 39.2, 35.6, 33.9]
task5_accs = [77.6, 40.6, 36.5, 33.6, 31.4, 31.8]
task6_accs = [76.2, 44.2, 36.4, 34.5, 33.6]
task7_accs = [74.2, 44.9, 38.7, 33.9]
task8_accs = [74.7, 42.4, 35.5]
task9_accs = [69.89, 37.4]
task10_accs = [76.2]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/tinyimg_herding_kaiser_criterion.png')

plt.show()

print('Forgetting:', 43.22)
# Out:
# Forgetting: 43.22

# %% [markdown]
# ### ER-ACE via Herding -- Class-IL Split-TinyImageNet

# %% [markdown]
# #### Buffer Size = 200

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [75.1, 41.8, 23.2, 16.2, 11.2, 7.5, 4.39, 4.2, 3.4, 2.6]
task2_accs = [69.89, 27.6, 16.9, 10.7, 9.3, 7.8, 5, 2.9, 5]
task3_accs = [76.6, 36.1, 23, 16.3, 9.7, 7.1, 6.4, 4]
task4_accs = [78.9, 28.59, 20, 10.8, 8.6, 8.2, 6.7]
task5_accs = [78.5, 27.3, 15.2, 13.7, 6.5, 7.6]
task6_accs = [76.5, 22.1, 17.8, 9.3, 9.3]
task7_accs = [77, 27.7, 15.5, 11.2]
task8_accs = [75.6, 20.9, 14.0]
task9_accs = [70, 21.6]
task10_accs = [76.9]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/tinyimg_herding_200.png')

plt.show()

print('Forgetting:', 66.23)
# Out:
# Forgetting: 66.23

# %% [markdown]
# #### Buffer Size = 500

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [76.7, 48.5, 37.1, 24.9, 20.2, 14.89, 12.1, 13.4, 10.4, 7.1]
task2_accs = [69.19, 33.8, 23.5, 17.59, 14.39, 12.4, 10.8, 8.1, 5.7]
task3_accs = [75.9, 41.6, 29.7, 17.4, 16.3, 13.6, 12.1, 9.3]
task4_accs = [77, 40.69, 27.90, 19.6, 17.9, 13.2, 12.7]
task5_accs = [77, 33.4, 24.9, 21.2, 17, 13.4]
task6_accs = [74.5, 31.4, 23.1, 19.9, 15.2]
task7_accs = [76, 32.7, 24.3, 15.2]
task8_accs = [72.8, 30.5, 21.6]
task9_accs = [71, 24.4]
task10_accs = [77.3]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/tinyimg_herding_500.png')

plt.show()

print('Forgetting:', 60.58)
# Out:
# Forgetting: 60.58

# %% [markdown]
# #### Buffer Size = 5120

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [80.30, 66.3, 53.80, 53, 45.1, 41, 39.1, 35.69, 32.9, 23.79]
task2_accs = [63.3, 47, 40.6, 36.8, 31.2, 32.4, 27.8, 22.7, 20]
task3_accs = [72.1, 55.1, 48.9, 41.6, 38.4, 35.5, 33.6, 28.1]
task4_accs = [75, 54.7, 47.09, 41.6, 39.2, 34.8, 32.8]
task5_accs = [73.1, 45.1, 42, 37.3, 32.9, 27.7]
task6_accs = [73.6, 43.6, 34.69, 35.6, 28.0]
task7_accs = [74.3, 45.7, 41, 29.59]
task8_accs = [73.3, 42.9, 36.1]
task9_accs = [66.8, 38.9]
task10_accs = [74.6]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/tinyimg_herding_5120.png')

plt.show()

print('Forgetting:', 42.97)
# Out:
# Forgetting: 42.97

# %% [markdown]
# #### Intracluster Variance

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [76, 76.7, 67.8, 63.4, 61.1, 58.4, 57.3, 53.9, 52.8, 51.5]
task2_accs = [27.5, 62.6, 57.8, 53.3, 50.3, 47.9, 46.8, 44.6, 45.1]
task3_accs = [25.1, 67.6, 63.6, 61.6, 56.9, 56.9, 53.6, 52.7]
task4_accs = [22.9, 64.6, 61.5, 58.9, 57.9, 56.8, 53.6]
task5_accs = [14.8, 61.5, 57.9, 56.1, 53.6, 51.7]
task6_accs = [14.89, 58.4, 53.2, 50.4, 49.6]
task7_accs = [17.2, 59.4, 55.3, 52]
task8_accs = [15, 56.49, 51.3]
task9_accs = [5.2, 50.7]
task10_accs = [0.2]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/tinyimg_herding_intracluster_variance.png')

plt.show()

print('Forgetting:', 11.08)
# Out:
# Forgetting: 11.08

# %% [markdown]
# #### Kaiser Criterion

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [80, 71.5, 61.9, 56.99, 54.1, 50.4, 48.1, 47, 44, 41.8]
task2_accs = [33.6, 58.19, 48, 44, 42, 40.3, 37.2, 36.3, 37]
task3_accs = [31.1, 60.6, 59.6, 56.1, 50.8, 49.5, 47.5, 46.1]
task4_accs = [25.8, 61.9, 56.8, 53.9, 53.2, 51.1, 47.6]
task5_accs = [22.1, 60.6, 54.2, 49.4, 46.4, 42.6]
task6_accs = [17.5, 54.2, 49.4, 46.4, 42.6]
task7_accs = [20.1, 56.89, 51.4, 49.6]
task8_accs = [14.89, 52.8, 46.9]
task9_accs = [7.8, 48]
task10_accs = [1.4]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/tinyimg_herding_kaiser_criterion.png')

plt.show()

print('Forgetting:', 14.11)
# Out:
# Forgetting: 14.11
