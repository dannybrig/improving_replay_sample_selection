# %% [markdown]
# ### DER via Herding -- Class-IL Split-CIFAR100

# %% [markdown]
# #### Buffer Size = 200

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [89.3, 19.90, 10.8, 6.9, 4.7, 1.5, 2.7, 1.0, 0.0, 0.1]
task2_accs = [87.4, 13.9, 2.9, 1.2, 0.3, 0.3, 0.1, 0.0, 0.0]
task3_accs = [87.9, 13.0, 4.7, 4.1, 1.7, 0.2, 0.1, 0.0]
task4_accs = [88.8, 11.1, 1.79, 2.3, 0.6, 0.6, 0.0]
task5_accs = [90.10, 13.9, 4.8, 1.6, 0.4, 0.3]
task6_accs = [88.3, 20.59, 8.79, 1.79, 0.2]
task7_accs = [89.0, 2.19, 2.19, 0.2]
task8_accs = [89.5, 7.1, 1.2]
task9_accs = [89.1, 2.9]
task10_accs = [93.10]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/cifar100_herding_200.png')

plt.show()

print('Forgetting:', 88.27)
# Out:
# Forgetting: 88.27

# %% [markdown]
# #### Buffer Size = 500

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [87.3, 35.8, 25.7, 19.40, 13.3, 11.2, 13.0, 7.5, 2.6, 5.6]
task2_accs = [86.8, 26.0, 9.1, 3.8, 4.5, 4.39, 0.5, 0.1, 0.2]
task3_accs = [89.0, 26.5, 9.5, 11.89, 7.8, 2.8, 1.0, 0.3]
task4_accs = [87.8, 22.1, 9.5, 5.5, 1.5, 1.79, 0.2]
task5_accs = [89.0, 23.7, 10.6, 1.9, 1.2, 1.3]
task6_accs = [87.0, 30.59, 11.60, 4.0, 1.0]
task7_accs = [89.0, 10.0, 12.1, 2.5]
task8_accs = [87.8, 21.5, 9.5]
task9_accs = [91.10, 9.9]
task10_accs = [93.4]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/cifar100_herding_500.png')

plt.show()

print('Forgetting:', 84.92)
# Out:
# Forgetting: 84.92

# %% [markdown]
# #### Buffer Size = 5120

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [87.9, 82.6, 73.6, 69.6, 64.8, 59.09, 57.19, 53.40, 48.1, 48.6]
task2_accs = [84.6, 72.39, 62.7, 58.4, 56.49, 53.2, 51.4, 43.7, 44.0]
task3_accs = [87.0, 68.5, 59.3, 61.7, 55.5, 53.4, 53.4, 53.1]
task4_accs = [87.1, 64.3, 60.9, 54.0, 55.30, 48.4, 40.69]
task5_accs = [86.9, 64.9, 59.0, 56.39, 49.6, 45.80]
task6_accs = [88.3, 66.7, 57.59, 54.6, 47.4]
task7_accs = [87.1, 56.8, 56.49, 46.4]
task8_accs = [85.3, 62.7, 48.0]
task9_accs = [90.5, 58.69]
task10_accs = [89.1]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/cifar100_herding_5120.png')

plt.show()

print('Forgetting:', 39.11)
# Out:
# Forgetting: 39.11

# %% [markdown]
# #### Intracluster Variance

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [89.1, 9, 8.1, 9, 8.6, 6.3, 9.1, 8, 6.3, 8.5]
task2_accs = [88.6, 0.2, 0, 0, 0, 0, 0, 0, 0]
task3_accs = [87.6, 0, 0, 0, 0, 0, 0, 0]
task4_accs = [89.9, 0, 0, 0, 0, 0, 0]
task5_accs = [88.2, 0.2, 0, 0, 0, 0]
task6_accs = [89.3, 0, 0, 0, 0]
task7_accs = [89.5, 0, 0, 0]
task8_accs = [87.8, 0, 0]
task9_accs = [91.5, 0]
task10_accs = [92.7]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/cifar100_herding_intracluster_variance.png')

plt.show()

print('Forgetting:', 88.11)
# Out:
# Forgetting: 88.11

# %% [markdown]
# #### Kaiser Criterion

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [87.9, 9.5, 12.5, 11.4, 11.2, 7.1, 8.3, 9, 7.8, 11.7]
task2_accs = [80.3, 0, 0, 0, 0, 0, 0, 0, 0]
task3_accs = [88.8, 0, 0, 0, 0, 0, 0, 0]
task4_accs = [88.3, 0, 0, 0, 0, 0, 0]
task5_accs = [88.6, 0.3, 0, 0, 0, 0]
task6_accs = [86, 0.1, 0, 0, 0]
task7_accs = [89.8, 0.2, 0, 0]
task8_accs = [88.7, 0.1, 0]
task9_accs = [90.1, 0]
task10_accs = [92.6]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/cifar100_herding_kaiser_criterion.png')

plt.show()

print('Forgetting:', 87.01)
# Out:
# Forgetting: 87.01

# %% [markdown]
# ### ER via Herding -- Class-IL Split-CIFAR100

# %% [markdown]
# #### Buffer Size = 200

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [86.3, 35.09, 24, 18.5, 11.6, 10.9, 11.5, 3.9, 3, 3]
task2_accs = [83.89, 32.2, 10.5, 9.1, 7.1, 7.3, 4.6, 2, 3.3]
task3_accs = [85.39, 32, 18.8, 19.4, 11.5, 7.7, 8.5, 5.89]
task4_accs = [85.9, 23.2, 12.3, 8.9, 4.8, 3.69, 1.79]
task5_accs = [88.6, 24.2, 20.59, 9.9, 9.6, 8.1]
task6_accs = [88.2, 31.3, 21.4, 12.8, 6.8]
task7_accs = [86.8, 10.4, 14.7, 8.3]
task8_accs = [86.8, 23.5, 11.]
task9_accs = [89.8, 15.6]
task10_accs = [91.8]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/cifar100_herding_200.png')

plt.show()

print('Forgetting:', 79.73)
# Out:
# Forgetting: 79.73

# %% [markdown]
# #### Buffer Size = 500

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [86.3, 51.2, 40.5, 33.9, 26.3, 20.59, 18.6, 17.9, 11.1, 9.5]
task2_accs = [84.7, 46.3, 26, 23.59, 20.59, 18.2, 15.2, 9.1, 9.2]
task3_accs = [87.9, 45.1, 29.7, 30.8, 22.1, 18.5, 17.2, 14.8]
task4_accs = [86.7, 37.2, 30, 21.8, 20.8, 16.6, 8.4]
task5_accs = [87.8, 40, 33.4, 25.5, 22.4, 17.2]
task6_accs = [88.3, 42.6, 32.3, 25.2, 15]
task7_accs = [86.8, 28, 28.29, 22]
task8_accs = [86.1, 35.4, 19.5]
task9_accs = [90.1, 27.5]
task10_accs = [92.7]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/cifar100_herding_500.png')

plt.show()

print('Forgetting:', 71.27)
# Out:
# Forgetting: 71.27

# %% [markdown]
# #### Buffer Size = 5120

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [85.2, 80.5, 71.5, 66.7, 62.5, 56.69, 53.9, 51.7, 45.7, 43.3]
task2_accs = [77.4, 68.3, 62.9, 56.3, 50.7, 50.3, 46.3, 39.5, 37.9]
task3_accs = [82.1, 72.3, 63.3, 62.5, 56.49, 53.2, 51.3, 49.5]
task4_accs = [83.8, 65.6, 60.8, 53.4, 52.2, 49.2, 39.6]
task5_accs = [82.5, 62.7, 60.7, 56.0, 51.1, 45.2]
task6_accs = [83.8, 67.3, 58.4, 53.8, 48.8]
task7_accs = [84.8, 56.9, 55.9, 48.9]
task8_accs = [82.39, 61.6, 46.4]
task9_accs = [86.1, 59.6]
task10_accs = [88.7]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/cifar100_herding_5120.png')

plt.show()

print('Forgetting:', 36.54)
# Out:
# Forgetting: 36.54

# %% [markdown]
# #### Intracluster Variance

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [86.8, 64.6, 58.5, 58.89, 57.19, 53.6, 54.1, 53.88, 51.6, 51.9]
task2_accs = [83.2, 64.2, 53.6, 51, 52.7, 50.4, 49.5, 44.6, 45.2]
task3_accs = [84.39, 68.5, 61.7, 62.3, 58.6, 57.7, 57.9, 53.7]
task4_accs = [86.7, 65.2, 61.3, 55.5, 53.1, 53.4, 47.1]
task5_accs = [83.1, 64.6, 63.2, 58.5, 57.8, 52]
task6_accs = [83.3, 68.6, 61, 61.3, 55.6]
task7_accs = [83.6, 61.4, 60.6, 56.5]
task8_accs = [82.6, 65.7, 54.6]
task9_accs = [85.6, 66.5]
task10_accs = [85.3]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/cifar100_herding_intracluster_variance.png')

plt.show()

print('Forgetting:', 30.67)
# Out:
# Forgetting: 30.67

# %% [markdown]
# #### Kaiser Criterion

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [87.4, 56.3, 51.3, 49.7, 46.8, 45.6, 44.8, 44.7, 41.6, 41.6]
task2_accs = [85.2, 59.09, 49.3, 44.8, 45.3, 45.3, 41.9, 37.2, 37.3]
task3_accs = [86.1, 60, 52.8, 52.9, 48.5, 45.6, 46.6, 45.5]
task4_accs = [86.3, 58.5, 52.2, 52.7, 49.8, 48.6, 37.9]
task5_accs = [86.5, 59.1, 55.6, 51.1, 48.3, 42.4]
task6_accs = [87.2, 63.9, 55.8, 53.2, 47.4]
task7_accs = [86.2, 51.4, 56.1, 50]
task8_accs = [85.8, 60.6, 45.6]
task9_accs = [88.6, 61]
task10_accs = [88.7]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/cifar100_herding_kaiser_criterion.png')

plt.show()

print('Forgetting:', 41.1)
# Out:
# Forgetting: 41.1

# %% [markdown]
# ### ER-ACE via Herding -- Class-IL Split-CIFAR100

# %% [markdown]
# #### Buffer Size = 200

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [89.7, 57.69, 45.9, 36.6, 27.6, 25.4, 21.8, 14.79, 17.2, 17.29]
task2_accs = [85.2, 54.7, 32.4, 28.4, 19.9, 14.29, 13.9, 12, 11.6]
task3_accs = [85.2, 52.8, 38.9, 37.8, 25.1, 20.9, 17.8, 18.9]
task4_accs = [87, 49.4, 36.3, 24.3, 22.7, 18.7, 13.7]
task5_accs = [84.8, 47.8, 37.8, 27.1, 27.3, 23.3]
task6_accs = [85.8, 49.3, 37, 29.5, 23.9]
task7_accs = [85.8, 35.9, 31.1, 28.7]
task8_accs = [85.2, 40.4, 31.5] 
task9_accs = [85.39, 43.4]
task10_accs = [88.4]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/cifar100_herding_200.png')

plt.show()

print('Forgetting:', 62.42)
# Out:
# Forgetting: 62.42

# %% [markdown]
# #### Buffer Size = 500

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [88.8, 68, 55.4, 46.5, 39.8, 36.7, 30.5, 31.2, 27.5, 25.5]
task2_accs = [82.39, 56.39, 40.5, 36.4, 31.8, 26.5, 25.5, 23.5, 20.59]
task3_accs = [86.4, 60.4, 50.8, 48.3, 43.1, 33.8, 34.3, 32.9]
task4_accs = [84.8, 55.0, 48.4, 35.6, 31.8, 26.7, 19.7]
task5_accs = [83.2, 54.2, 45.3, 41.8, 39.4, 31.4]
task6_accs = [85.1, 59.4, 44.5, 43.9, 35]
task7_accs = [84.7, 41.69, 43.6, 33.8]
task8_accs = [84, 49, 35.8]
task9_accs = [87.6, 49.7]
task10_accs = [88.3]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/cifar100_herding_500.png')

plt.show()

print('Forgetting:', 53.62)
# Out:
# Forgetting: 53.62

# %% [markdown]
# #### Buffer Size = 5120

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [88.9, 85.8, 76.7, 72, 69.6, 65.5, 61.4, 58.69, 56.69, 57.59]
task2_accs = [79.1, 74.6, 67.4, 62.8, 60.8, 57.69, 55.9, 50.8, 48.19]
task3_accs = [83.8, 74.4, 68.89, 67.80, 64.9, 61.4, 57.3, 56.99]
task4_accs = [81, 68.5, 63.80, 61.19, 57.9, 56.0, 47.69]
task5_accs = [82.39, 69.19, 64.4, 58.3, 55.6, 51.80]
task6_accs = [82.19, 72.3, 64.3, 61, 57.1]
task7_accs = [83, 62.4, 63.1, 58.4]
task8_accs = [79, 64, 55.4]
task9_accs = [84.6, 67.4]
task10_accs = [83.6]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/cifar100_herding_5120.png')

plt.show()

print('Forgetting:', 27.01)
# Out:
# Forgetting: 27.01

# %% [markdown]
# #### Intracluster Variance

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [86, 85.5, 78.2, 59.59, 68.7, 63.4, 61.4, 61.5, 59.8, 58.09]
task2_accs = [23.5, 77.3, 72.7, 64.8, 63.6, 60.69, 60, 57.69, 56.69]
task3_accs = [24.4, 76.1, 71, 68.2, 66.2, 63.9, 62.6, 62.3]
task4_accs = [23.5, 74.6, 69.69, 67.4, 63.7, 62.7, 63]
task5_accs = [17.2, 69, 66.1, 65, 63.8, 61]
task6_accs = [21.9, 71.8, 68.8, 67, 64.9]
task7_accs = [12.8, 70, 63.9, 65.2]
task8_accs = [4.2, 63.3, 61.9]
task9_accs = [4.5, 71]
task10_accs = [0.1]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/cifar100_herding_intracluster_variance.png')

plt.show()

print('Forgetting:', 10.5)
# Out:
# Forgetting: 10.5

# %% [markdown]
# #### Kaiser Criterion

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [87.5, 82.89, 70.8, 64.5, 61.4, 56.89, 55.9, 53.3, 52.4, 50.2]
task2_accs = [30.3, 74, 67.8, 62.5, 59.9, 53.9, 53.7, 51.1, 50]
task3_accs = [33.4, 69.8, 68.8, 60.9, 59.59, 56.9, 56.0, 55.2]
task4_accs = [30.7, 73.1, 68.1, 63.9, 62.4, 57.59, 57.09]
task5_accs = [25.4,  67.6, 61.8, 61.6, 58.8, 56.9]
task6_accs = [27.4, 68.6, 66.3, 61.8, 60.6]
task7_accs = [22.5, 67, 61.4, 59.4]
task8_accs = [11.7, 60.19, 59.59]
task9_accs = [12, 68.3]
task10_accs = [1.09]

ticks = ['Task {}'.format(i) for i in range(1,11)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs, task6_accs, task7_accs, task8_accs, task9_accs, task10_accs]
x = np.arange(1, 11)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,10), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, rotation=45, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/cifar100_herding_kaiser_criterion.png')

plt.show()

print('Forgetting:', 13.17)
# Out:
# Forgetting: 13.17
