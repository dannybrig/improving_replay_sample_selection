# %% [markdown]
# ### DER via Herding-- Class-IL Split-CIFAR10

# %% [markdown]
# #### Buffer Size = 200

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [98.65, 40.45, 55.60, 38.05, 12.15]
task2_accs = [93.4, 1.65, 0.85, 1.7]
task3_accs = [96.3, 7.39, 7.1]
task4_accs = [98.65, 24.15]
task5_accs = [98.05]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/cifar10_herding_200.png')

plt.show()

print('Forgetting:', 85.475)
# Out:
# Forgetting: 85.475

# %% [markdown]
# #### Buffer Size = 500

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [98.65, 54.49, 56.49, 53.6, 25.15]
task2_accs = [93.60, 8.35, 4.1, 15.1]
task3_accs = [96.2, 15.55, 30.15]
task4_accs = [99.0, 59.59]
task5_accs = [96.6]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/cifar10_herding_500.png')

plt.show()

print('Forgetting:', 64.36)
# Out:
# Forgetting: 64.36

# %% [markdown]
# #### Buffer Size = 5120

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [97.95, 84.89, 87.15, 90.64, 73.3]
task2_accs = [93.30, 56.55, 54.2, 54.6]
task3_accs = [95.85, 56.99, 67.85]
task4_accs = [98.95, 80.2]
task5_accs = [97.5]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/cifar10_herding_5120.png')

plt.show()

print('Forgetting:', 27.52)
# Out:
# Forgetting: 27.52

# %% [markdown]
# #### Intracluster Variance

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [98.95, 8.1, 11.3, 19.05, 12.65]
task2_accs = [93.1, 0, 0, 0]
task3_accs = [95.55, 0, 0]
task4_accs = [93.05, 0]
task5_accs = [98.05]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/cifar10_herding_intracluster_variance.png')

plt.show()

print('Forgetting:', 92)
# Out:
# Forgetting: 92

# %% [markdown]
# #### Kasier Criterion

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [98.65, 51.15, 60.05, 66.3, 70.65]
task2_accs = [94.25, 0, 0, 0]
task3_accs = [95.39, 0, 0]
task4_accs = [98.85, 0]
task5_accs = [97.1]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/der/cifar10_herding_kaiser_criterion.png')

plt.show()

print('Forgetting:', 79.125)
# Out:
# Forgetting: 79.125

# %% [markdown]
# ### ER via Herding -- Class-IL Split-CIFAR10

# %% [markdown]
# #### Buffer Size = 200

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [98.55, 69, 65.8, 65.05, 26.95]
task2_accs = [92.2, 17.7, 12.4, 18.6]
task3_accs = [94.05, 27.65, 43.9]
task4_accs = [98.45, 68.7]
task5_accs = [98.15]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/cifar10_herding_200.png')

plt.show()

print('Forgetting:', 56.275)
# Out:
# Forgetting: 56.275

# %% [markdown]
# #### Buffer Size = 500

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [98.8, 80.85, 78.2, 82.05, 49.45]
task2_accs = [90.60, 30.34, 27.35, 31.05]
task3_accs = [96.15, 42.69, 59.15]
task4_accs = [98.6, 79.7]
task5_accs = [98]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/cifar10_herding_500.png')

plt.show()

print('Forgetting:', 41.2)
# Out:
# Forgetting: 41.2

# %% [markdown]
# #### Buffer Size = 5120

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [98.85, 96.3, 94.69, 94.35, 82.05]
task2_accs = [90.95, 73.85, 67.85, 73.1]
task3_accs = [93.2, 81.95, 83.8]
task4_accs = [96.95, 91.14]
task5_accs = [96.85]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/cifar10_herding_5120.png')

plt.show()

print('Forgetting:', 12.46)
# Out:
# Forgetting: 12.46

# %% [markdown]
# #### Intracluster Variance

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [98.65, 65, 73.95, 80, 57.69]
task2_accs = [92.2, 27.65, 29.4, 44.9]
task3_accs = [96.05, 45.2, 61.05]
task4_accs = [98.35, 82.1]
task5_accs = [96.85]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/cifar10_herding_intracluster_variance.png')

plt.show()

print('Forgetting:', 34.875)
# Out:
# Forgetting: 34.875

# %% [markdown]
# #### Kaiser Criterion

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [99.05, 76.44, 84.35, 84.7, 79.5]
task2_accs = [91.45, 41.65, 44.75, 53.94]
task3_accs = [94.89, 65.14, 71.75]
task4_accs = [98.4, 88.3]
task5_accs = [87.25]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er/cifar10_herding_kaiser_criterion.png')

plt.show()

print('Forgetting:', 27.575)
# Out:
# Forgetting: 27.575

# %% [markdown]
# ### ER-ACE via Herding -- Class-IL Split-CIFAR10

# %% [markdown]
# #### Buffer Size = 200

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [98.8, 77.7, 81.35, 78.10, 53.1]
task2_accs = [83.95, 40.65, 31, 34.69]
task3_accs = [90.1, 61.65, 53.1]
task4_accs = [95.45, 76.14]
task5_accs = [93.7]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/cifar10_herding_200.png')

plt.show()

print('Forgetting:', 37.81)
# Out:
# Forgetting: 37.81

# %% [markdown]
# #### Buffer Size = 500

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [98.65, 87.15, 88.4, 84.5, 62.94]
task2_accs = [86.3, 60.6, 53.34, 49.35]
task3_accs = [85.75, 75.6, 62.4]
task4_accs = [92.80, 83.6]
task5_accs = [96.75]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/cifar10_herding_500.png')

plt.show()

print('Forgetting:', 26.3)
# Out:
# Forgetting: 26.3

# %% [markdown]
# #### Buffer Size = 5120

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [98.45, 94.55, 94.75, 93.55, 80.7]
task2_accs = [91.95, 68.2, 63.3, 74.15]
task3_accs = [93.5, 83.65, 81.45]
task4_accs = [97.8, 91.8]
task5_accs = [97.35]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/cifar10_herding_5120.png')

plt.show()

print('Forgetting:', 13.39)
# Out:
# Forgetting: 13.39

# %% [markdown]
# #### Intracluster Variance

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [99.05, 89.4, 86.45, 83.55, 76]
task2_accs = [15.7, 85.95, 70.05, 66.3]
task3_accs = [4.85, 76.9, 67.85]
task4_accs = [23.3, 83.3]
task5_accs = [19.25]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/cifar10_herding_intracluster_variance.png')

plt.show()

print('Forgetting:', 12.93)
# Out:
# Forgetting: 12.93

# %% [markdown]
# #### Kaiser Criterion

# %%
import numpy as np
from matplotlib import pyplot as plt

task1_accs = [0.449, 0.449, 0.449, 0.449, 78.10]
task2_accs = [0, 0, 0, 47.69]
task3_accs = [2.05, 2.05, 44.6]
task4_accs = [34.59, 82.6]
task5_accs = [73.35]

ticks = ['Task {}'.format(i) for i in range(1,6)]
task_accs = [task1_accs, task2_accs, task3_accs, task4_accs, task5_accs]
x = np.arange(1, 6)

fig, axs = plt.subplots(figsize=(7.4, 4.8))
for i, accs in zip(range(0,5), task_accs):
    axs.plot(x[i:], accs, marker='.', markersize = 15, label = 'Task {}'.format(i+1))
    
axs.grid()
axs.set_xticks(x)
axs.set_xticklabels(ticks, fontsize = 16)
axs.tick_params(axis='y', labelsize=16)
axs.set_ylabel('Accuracy', fontsize = 20)
axs.set_ylim((-4.9275, 103.47749999999999))
axs.legend(bbox_to_anchor=(1.0001, 0), loc="lower left", prop={'size': 16})
fig.tight_layout()
fig.savefig('./figures/er-ace/cifar10_herding_kaiser_criterion.png')

plt.show()

print('Forgetting:', 0)
# Out:
# Forgetting: 0
